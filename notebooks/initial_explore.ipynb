# %% [markdown]
# # Exploring the Adver-City Dataset
#
# This notebook explores the Adver-City Dataset, a synthetic dataset for cooperative perception in adverse weather conditions. The dataset is located here: https://labs.cs.queensu.ca/quarrg/datasets/adver-city/.
#
#
#  The datafiles are formatted as follows:
# `[prefix]_[weather]_[density].7z`, where:
# - `prefix` denotes one of various CARLA maps and/or scenario families
# - `weather` denotes the weather condition code
# - `density` denote the density of the scene (`['dense', 'sparse']`)
#
# Notes:
# - ensure to source virtual environment located at `./venv/bin/python` before running: `source venv/bin/activate`
# - requirements have been exported to `pip freeze > requirements.txt`
# - data ingests and extracts from data format `.7z`, which requires a system executable outside venv (hence, our use of `subprocess`)
# - to unzip the `.7z` files using this subprocess, install p7zip as follows: `brew install p7zip`
#
# This data exploration notebook allows us to familiarize ourselves with the dataset. Along the way, we build some utility functions for data ingestion and manipulation that will be useful later on.
#
# ## Dev notes (updated: 29 Dec)
#  - This notebook has served its purpose and given me a good idea of the dataset
#  - The dataset is huge, so I will need to do some selective sampling to bring it down constructively
#  - I will start a new notebook for this part

# %% [markdown]
# ##  Access the Data
#
# Import necessary libraries and set project root

# %%
# imports (standard)
from pathlib import Path
import os
import yaml

# move to project project directory 
cwd = Path.cwd()
if cwd.name == "notebooks":
    os.chdir(cwd.parent)
    print("changed to root directory:", Path.cwd())
else:
    print("already in project root:", Path.cwd())

# imports (from project directory)
from src.ingestion.download import build_filename, download_file
from src.ingestion.download import download_files, build_filenames
from src.ingestion.extract import extract_file, extract_files
from src.utils.file_operations import get_agent_ids, find_imgs, list_image_sizes
from src.utils.visualization import show_images_grid, print_folder_tree
from src.ingestion.index import build_index, build_index_multi, save_index
# Out:
# already in project root: /Users/tjards/Library/CloudStorage/Dropbox/adjunctQueens/code/pytorch_project_advercity

# %% [markdown]
# Create dictionaries of valid values for easier access and error checking.

# %%
# various CARLA maps and scenario families
VALID_PREFIX = {
    "rcnj", 
    "ri", 
    "rsnj", 
    "ui", 
    "unj"
}

# weather types
VALID_WEATHER = {
    "cd": "clear day",
    "cn": "clear night",
    "fd": "fog day",
    "fn": "fog night",
    "hrd": "heavy rain day",
    "hrn": "heavy rain night",
    "srd": "soft rain day",
    "srn": "soft rain night",
    "gd": "glare day",
    "fhrd": "fog + heavy rain day",
    "fhrn": "fog + heavy rain night",
}

# density of the scene
VALID_DENSITY = {
    "s": "sparse",
    "d": "dense",
}

# %% [markdown]
# Configure the remote server URL and specify which file(s) to download for exploration.

# %%
# path to where files are stored
DATA_DIR = "./exploration/data"
BASE_URL = "https://www.frdr-dfdr.ca/repo/files/1/published/publication_1079/submitted_data"

# specify which file (automate this later)
PREFIX = "rcnj"
WEATHER = "cn"
#WEATHER = "hrn"
DENSITY = "s"

FILENAME = build_filename(
    prefix=PREFIX,
    weather=WEATHER,
    density=DENSITY,
    VALID_PREFIX=VALID_PREFIX,
    VALID_WEATHER=VALID_WEATHER,
    VALID_DENSITY=VALID_DENSITY,
    ARCHIVE_EXT = ".7z"
)

print('filename: ', FILENAME)
# Out:
# filename:  rcnj_cn_s.7z

# %% [markdown]
# Download the file (if not aleady done).

# %%
print('requesting', FILENAME, ' from remote server...') 
DOWNLOAD_URL = f"{BASE_URL}/{FILENAME}"
print('from url:', DOWNLOAD_URL)
FILE_PATH = download_file(
    url=DOWNLOAD_URL, 
    destination=Path(DATA_DIR) / FILENAME, 
    filename=FILENAME, 
    timeout=60
)
print('file located at: ', FILE_PATH)
# Out:
# requesting rcnj_cn_s.7z  from remote server...
# from url: https://www.frdr-dfdr.ca/repo/files/1/published/publication_1079/submitted_data/rcnj_cn_s.7z
# file located at:  exploration/data/rcnj_cn_s.7z

# %% [markdown]
# Extract the contents of the downloaded file.

# %%
DIR_EXTRACTED = extract_file(
    DIR_IN=DATA_DIR,
    FILENAME_IN=FILENAME,
    DIR_OUT=DATA_DIR+"/extracted"
)
# Out:
# Already extracted, skipping:
#   ./exploration/data/extracted/rcnj_cn_s

# %% [markdown]
# ## Discover Structure
#
# Display the folder structure as a tree

# %%
print('directory tree for ', DIR_EXTRACTED, ':')
print_folder_tree(DIR_EXTRACTED, max_depth=1)
AGENT_IDS = get_agent_ids(DIR_EXTRACTED, include_negative=True)
print('list of AGENT IDs in this folder: \n', list(AGENT_IDS))
# Out:
# directory tree for  ./exploration/data/extracted/rcnj_cn_s :
# rcnj_cn_s/
# ├── -1/
# ├── -2/
# ├── 1011/
# ├── 1025/
# ├── 1039/
# ├── data_protocol.yaml
# └── summary.yaml
# list of AGENT IDs in this folder:
#  ['-2', '-1', '1011', '1025', '1039']

# %% [markdown]
# We can see two .yaml files with configuration and metadata and agent/vehicle IDs. Let's look at the summary.yaml file to get an overview of the dataset.

# %%
DATA_SUMMARY_PATH = DIR_EXTRACTED+"/summary.yaml"
print("summary for data at:", DATA_SUMMARY_PATH)
with open(DATA_SUMMARY_PATH, "r") as f:
    summary_data = yaml.safe_load(f)
print(yaml.safe_dump(summary_data, sort_keys=False))
# Out:
# summary for data at: ./exploration/data/extracted/rcnj_cn_s/summary.yaml
# simulation: rcnj_cn_s
# scenario: rural_curved_non_junction
# weather: clear
# time_of_day: night
# density: sparse
# num_frames: 190
# num_vehicles: 21
# num_walkers: 0
# frames:
#   60:
#     cav_speeds:
#       ego: 37.48457299049714
#       cav1: 27.921569795082934
#       cav2: 38.47125400005063
#     num_annotations: 18
#     1075:
#       class: car
#       speed: 26.47415158892431
#       distance_to_ego: 49.57381057739258
#       angle_to_ego: -121.1683120727539
#     1076:
#       class: van
#       speed: 18.96085240963301
#     1082:
#       class: van
#       speed: 12.681598250566514
#     1084:
#       class: bicycle
#       speed: 12.92454995295947
#     1085:
#       class: car
#       speed: 20.442992010551688
#     1086:
#       class: van
#       speed: 25.435691705515506
#     1088:
#       class: car
#       speed: 24.747269309299263
#     1091:
#       class: truck
#       speed: 19.747792429655863
#       distance_to_ego: 59.07536697387695
#       angle_to_ego: 59.45049285888672
#     1095:
#       class: van
#       speed: 12.476347592357811
#     1097:
#       class: bicycle
#       speed: 14.43121411488865
#     1077:
#       speed: 14.400759372028798
#     1090:
#       class: bicycle
#       speed: 4.897700587005436e-05
#     1096:
#       class: bicycle
#       speed: 18.604086218219628
#       distance_to_ego: 2.467540979385376
#       angle_to_ego: -173.34142684936523
#   65:
#     cav_speeds:
#       ego: 40.589190570870215
#       cav1: 20.448511602240696
#       cav2: 37.872196894753706
#     num_annotations: 19
#     1075:
#       class: car
#       speed: 26.441861416541926
#       distance_to_ego: 41.8388671875
#       angle_to_ego: -128.29268646240234
#     1076:
#       class: van
#       speed: 22.223803015354722
#     1082:
#       class: van
#       speed: 15.049764078252572
#     1084:
#       class: bicycle
#       speed: 13.019775651343915
#     1085:
#       class: car
#       speed: 19.32841922661501
#     1086:
#       class: van
#       speed: 26.564928467302636
#     1088:
#       class: car
#       speed: 24.94269738283156
#       distance_to_ego: 69.54443359375
#       angle_to_ego: -134.91999053955078
#     1091:
#       class: truck
#       speed: 18.447566232544187
#       distance_to_ego: 57.854854583740234
#       angle_to_ego: 52.8546142578125
#     1095:
#       class: van
#       speed: 12.478351951087497
#     1097:
#       class: bicycle
#       speed: 14.443247412042192
#     1077:
#       class: truck
#       speed: 30.307555521202488
#       distance_to_ego: 23.908775329589844
#       angle_to_ego: -140.5877914428711
#     1087:
#       class: car
#       speed: 16.298203068164774
#       distance_to_ego: 11.080641746520996
#       angle_to_ego: -156.74171447753906
#     1094:
#       class: car
#       speed: 12.680527836952656
#       distance_to_ego: 21.90027618408203
#       angle_to_ego: -135.13841247558594
#     1079:
#       class: car
#       speed: 14.384261268570256
#     1090:
#       class: bicycle
#       speed: 2.7213190968120832e-05
#     1096:
#       class: bicycle
#       speed: 18.781859472043035
#       distance_to_ego: 3.180569648742676
#       angle_to_ego: -176.2524299621582
#   66:
#     cav_speeds:
#       ego: 38.419521515636305
#       cav1: 21.892020075647117
#       cav2: 40.47999305215002
#     num_annotations: 17
#     1075:
#       class: car
#       speed: 26.448695565625513
#       distance_to_ego: 40.195247650146484
#       angle_to_ego: -131.31482696533203
#     1076:
#       class: van
#       speed: 23.075110883436604
#     1082:
#       class: van
#       speed: 15.748159776619197
#     1084:
#       class: bicycle
#       speed: 12.997047419621506
#     1085:
#       class: car
#       speed: 19.574406926017918
#     1086:
#       class: van
#       speed: 27.06022704223317
#     1088:
#       class: car
#       speed: 24.744000236952793
#       distance_to_ego: 67.99921417236328
#       angle_to_ego: -136.29471588134766
#     1091:
#       class: truck
#       speed: 18.369417446371333
#       distance_to_ego: 57.50582504272461
#       angle_to_ego: 49.8043212890625
#     1095:
#       class: van
#       speed: 12.471919884506983
#     1097:
#       class: bicycle
#       speed: 14.440496023364888
#     1077:
#       class: truck
#       speed: 29.510513991544556
#       distance_to_ego: 25.717620849609375
#       angle_to_ego: -140.2636489868164
#     1087:
#       class: car
#       speed: 17.489342722011394
#       distance_to_ego: 9.549978256225586
#       angle_to_ego: -160.55237579345703
#     1094:
#       class: car
#       speed: 13.503354569592792
#       distance_to_ego: 20.50680923461914
#       angle_to_ego: -139.3993682861328
#     1096:
#       angle_to_ego: 8.395912170410156
#     1091:
#       class: truck
#       speed: 24.36000443505178
#       distance_to_ego: 30.867843627929688
#       angle_to_ego: -57.20539855957031
#     1095:
#       class: van
#       speed: 22.827131802600526
#     1097:
#       class: bicycle
#       speed: 0.039635084708294
#   239:
#     cav_speeds:
#       ego: 32.56628410529967
#       cav1: 28.480826777537647
#       cav2: 22.132250648697564
#     num_annotations: 17
#     1089:
#       class: car
#       speed: 13.688941731431663
#     1075:
#       class: car
#       speed: 0.0007164271672775091
#     1077:
#       class: truck
#       speed: 0.0003745010307305921
#     1084:
#       class: bicycle
#       speed: 22.480891647344272
#     1087:
#       class: car
#       speed: 0.0005901514590700844
#     1088:
#       class: car
#       speed: 2.075623314473282
#     1094:
#       class: car
#       speed: 0.0008179879395123226
#     1076:
#       class: van
#       speed: 32.24696820029268
#       distance_to_ego: 45.80848693847656
#       angle_to_ego: -168.9205322265625
#     1086:
#       class: van
#       speed: 4.921511749334423
#     1090:
#       class: bicycle
#       speed: 2.0723567976579258e-07
#       distance_to_ego: 41.349342346191406
#       angle_to_ego: 9.264129638671875
#     1091:
#       class: truck
#       speed: 24.372993505003933
#       distance_to_ego: 30.7099609375
#       angle_to_ego: -57.122642517089844
#     1095:
#       class: van
#       speed: 23.097130709160783
#     1097:
#       class: bicycle
#       speed: 0.02590477845855866
#     1082:
#       class: van
#       speed: 0.004447099850927655
#       distance_to_ego: 112.64990234375
#       angle_to_ego: -78.72875213623047
#   240:
#     cav_speeds:
#       ego: 33.23951640225283
#       cav1: 29.270227343445487
#       cav2: 24.097702337654944
#     num_annotations: 16
#     1089:
#       class: car
#       speed: 12.969281702027473
#     1075:
#       class: car
#       speed: 0.000717226669866969
#     1077:
#       class: truck
#       speed: 0.00037732437566269735
#     1084:
#       class: bicycle
#       speed: 22.65743664224671
#     1087:
#       class: car
#       speed: 0.0005897963925477026
#     1088:
#       class: car
#       speed: 3.4082818722357855
#     1094:
#       class: car
#       speed: 0.000818251523392191
#     1076:
#       class: van
#       speed: 32.242933112969354
#       distance_to_ego: 46.084495544433594
#       angle_to_ego: -167.85128021240234
#     1086:
#       class: van
#       speed: 5.722257888902218
#       distance_to_ego: 65.97674560546875
#       angle_to_ego: -167.6563949584961
#     1090:
#       class: bicycle
#       speed: 5.153845581473095e-07
#       distance_to_ego: 41.02517318725586
#       angle_to_ego: 10.30145263671875
#     1091:
#       class: truck
#       speed: 21.542352313916652
#       distance_to_ego: 30.51512336730957
#       angle_to_ego: -56.657264709472656
#     1095:
#       class: van
#       speed: 23.04567303060831
#       distance_to_ego: 76.57122039794922
#       angle_to_ego: -75.22298431396484
#     1082:
#       class: van
#       speed: 0.9622170019706546
#       distance_to_ego: 112.92931365966797
#       angle_to_ego: -77.68927764892578
#   241:
#     cav_speeds:
#       ego: 31.59237411956808
#       cav1: 30.34550108624414
#       cav2: 26.57926200863534
#     num_annotations: 16
#     1089:
#       class: car
#       speed: 12.508625953546513
#     1075:
#       class: car
#       speed: 0.0007155232561320097
#       class: car
#       speed: 10.664572691705178
#     1075:
#       class: car
#       speed: 0.0007140395583126736
#     1077:
#       class: truck
#       speed: 0.0003766032384673871
#     1084:
#       class: bicycle
#       speed: 23.609884727989407
#     1087:
#       class: car
#       speed: 0.0005887560919997195
#     1088:
#       class: car
#       speed: 0.04280819762748354
#     1094:
#       class: car
#       speed: 0.0008193689973646607
#     1076:
#       class: van
#       speed: 32.24399069816425
#       distance_to_ego: 49.475067138671875
#       angle_to_ego: -155.8927001953125
#     1086:
#       class: van
#       speed: 12.114380464577923
#       distance_to_ego: 70.60200500488281
#       angle_to_ego: -155.81996154785156
#     1091:
#       class: truck
#       speed: 18.029509787745553
#       distance_to_ego: 29.466577529907227
#       angle_to_ego: -45.2645263671875
#     1095:
#       class: van
#       speed: 24.891300907322723
#       distance_to_ego: 82.9000015258789
#       angle_to_ego: -66.50431823730469
#     1097:
#       class: bicycle
#       speed: 7.058463532403238e-05
#       distance_to_ego: 39.27553939819336
#       angle_to_ego: 25.013572692871094
#     1090:
#       class: bicycle
#       speed: 6.18022849058382e-07
#       distance_to_ego: 38.733070373535156
#       angle_to_ego: 22.169044494628906
#   249:
#     cav_speeds:
#       ego: 23.34717102590657
#       cav1: 25.026257054476783
#       cav2: 15.508000634003174
#     num_annotations: 18
#     1081:
#       class: car
#       speed: 34.189616401462295
#     1089:
#       class: car
#       speed: 9.157044429536814
#     1075:
#       class: car
#       speed: 0.0007144374866663055
#     1077:
#       class: truck
#       speed: 0.00037919566027972985
#     1084:
#       class: bicycle
#       speed: 23.682795448696965
#     1087:
#       class: car
#       speed: 0.0005924380314139294
#     1088:
#       class: car
#       speed: 0.026764517920138464
#     1094:
#       class: car
#       speed: 0.0008194226715757828
#     1076:
#       class: van
#       speed: 32.2445251780846
#       distance_to_ego: 50.00251388549805
#       angle_to_ego: -154.50428771972656
#     1082:
#       class: van
#       speed: 2.20981706961152
#     1086:
#       class: van
#       speed: 12.695415582158285
#     1090:
#       class: bicycle
#       speed: 8.926783714058911e-07
#       distance_to_ego: 38.455284118652344
#       angle_to_ego: 23.568321228027344
#     1091:
#       class: truck
#       speed: 18.221975202014406
#       distance_to_ego: 29.377437591552734
#       angle_to_ego: -45.14634704589844
#     1095:
#       class: van
#       speed: 25.23888559658277
#       distance_to_ego: 83.59723663330078
#       angle_to_ego: -65.53121948242188
#     1097:
#       class: bicycle
#       speed: 6.876399822667074e-05
#       distance_to_ego: 39.096431732177734
#       angle_to_ego: 26.41284942626953

# %% [markdown]
# Here we can see the scenario is `rural_curved_non_junction` with `clear` weather during the `night`. The dataset contains total 21 agents/vehicles. The folders are for the data **data-producing agents/vehicles** (i.e., those with the cameras). Other agents/vehicles are annotated in various `frames'.

# %% [markdown]
# # Inspect Content
#
# Let's pick one specific agent and look a bit deeper.

# %%
AGENT_ID = AGENT_IDS[2] #optionally, specify directly as "1011", ... etc
print('directory tree for ', DIR_EXTRACTED+"/"+str(AGENT_ID), ':')
print_folder_tree(DIR_EXTRACTED+"/"+str(AGENT_ID), max_depth=2)
# Out:
# directory tree for  ./exploration/data/extracted/rcnj_cn_s/1011 :
# 1011/
# ├── 000060.yaml
# ├── 000060_camera0.png
# ├── 000060_camera1.png
# ├── 000060_camera2.png
# ├── 000060_camera3.png
# ├── 000060_gnss_imu.yaml
# ├── 000060_lidar.ply
# ├── 000060_semantic1.png
# ├── 000060_semantic2.png
# ├── 000060_semantic3.png
# ├── 000061.yaml
# ├── 000061_camera0.png
# ├── 000061_camera1.png
# ├── 000061_camera2.png
# ├── 000061_camera3.png
# ├── 000061_gnss_imu.yaml
# ├── 000061_lidar.ply
# ├── 000061_semantic0.png
# ├── 000061_semantic1.png
# ├── 000061_semantic2.png
# ├── 000061_semantic3.png
# ├── 000062.yaml
# ├── 000062_camera0.png
# ├── 000062_camera1.png
# ├── 000062_camera2.png
# ├── 000062_camera3.png
# ├── 000062_gnss_imu.yaml
# ├── 000062_lidar.ply
# ├── 000062_semantic0.png
# ├── 000062_semantic1.png
# ├── 000062_semantic2.png
# ├── 000062_semantic3.png
# ├── 000063.yaml
# ├── 000063_camera0.png
# ├── 000063_camera1.png
# ├── 000063_camera2.png
# ├── 000063_camera3.png
# ├── 000063_gnss_imu.yaml
# ├── 000063_lidar.ply
# ├── 000063_semantic0.png
# ├── 000063_semantic1.png
# ├── 000063_semantic2.png
# ├── 000063_semantic3.png
# ├── 000064.yaml
# ├── 000064_camera0.png
# ├── 000064_camera1.png
# ├── 000064_camera2.png
# ├── 000064_camera3.png
# ├── 000064_gnss_imu.yaml
# ├── 000064_lidar.ply
# ├── 000064_semantic1.png
# ├── 000064_semantic2.png
# ├── 000064_semantic3.png
# ├── 000065.yaml
# ├── 000065_camera0.png
# ├── 000065_camera1.png
# ├── 000065_camera2.png
# ├── 000065_camera3.png
# ├── 000065_gnss_imu.yaml
# ├── 000065_lidar.ply
# ├── 000065_semantic0.png
# ├── 000065_semantic1.png
# ├── 000065_semantic2.png
# ├── 000065_semantic3.png
# ├── 000066.yaml
# ├── 000066_camera0.png
# ├── 000066_camera1.png
# ├── 000066_camera2.png
# ├── 000066_camera3.png
# ├── 000066_gnss_imu.yaml
# ├── 000066_lidar.ply
# ├── 000066_semantic0.png
# ├── 000066_semantic1.png
# ├── 000066_semantic2.png
# ├── 000066_semantic3.png
# ├── 000067.yaml
# ├── 000067_camera0.png
# ├── 000067_camera1.png
# ├── 000067_camera2.png
# ├── 000067_camera3.png
# ├── 000067_gnss_imu.yaml
# ├── 000067_lidar.ply
# ├── 000067_semantic0.png
# ├── 000067_semantic1.png
# ├── 000067_semantic2.png
# ├── 000067_semantic3.png
# ├── 000068.yaml
# ├── 000068_camera0.png
# ├── 000068_camera1.png
# ├── 000068_camera2.png
# ├── 000068_camera3.png
# ├── 000068_gnss_imu.yaml
# ├── 000068_lidar.ply
# ├── 000068_semantic0.png
# ├── 000068_semantic1.png
# ├── 000068_semantic2.png
# ├── 000068_semantic3.png
# ├── 000069.yaml
# ├── 000069_camera0.png
# ├── 000069_camera1.png
# ├── 000069_camera2.png
# ├── 000069_camera3.png
# ├── 000069_gnss_imu.yaml
# ├── 000069_lidar.ply
# ├── 000069_semantic0.png
# ├── 000069_semantic1.png
# ├── 000069_semantic2.png
# ├── 000069_semantic3.png
# ├── 000070.yaml
# ├── 000070_camera0.png
# ├── 000070_camera1.png
# ├── 000070_camera2.png
# ├── 000070_camera3.png
# ├── 000070_gnss_imu.yaml
# ├── 000070_lidar.ply
# ├── 000070_semantic0.png
# ├── 000070_semantic1.png
# ├── 000070_semantic2.png
# ├── 000070_semantic3.png
# ├── 000071.yaml
# ├── 000071_camera0.png
# ├── 000071_camera1.png
# ├── 000071_camera2.png
# ├── 000071_camera3.png
# ├── 000071_gnss_imu.yaml
# ├── 000071_lidar.ply
# ├── 000071_semantic0.png
# ├── 000071_semantic1.png
# ├── 000071_semantic2.png
# ├── 000071_semantic3.png
# ├── 000072.yaml
# ├── 000072_camera0.png
# ├── 000072_camera1.png
# ├── 000072_camera2.png
# ├── 000072_camera3.png
# ├── 000072_gnss_imu.yaml
# ├── 000072_lidar.ply
# ├── 000072_semantic0.png
# ├── 000073.yaml
# ├── 000073_camera0.png
# ├── 000073_camera1.png
# ├── 000073_camera2.png
# ├── 000073_camera3.png
# ├── 000073_gnss_imu.yaml
# ├── 000073_lidar.ply
# ├── 000073_semantic0.png
# ├── 000073_semantic1.png
# ├── 000073_semantic2.png
# ├── 000073_semantic3.png
# ├── 000074.yaml
# ├── 000074_camera0.png
# ├── 000074_camera1.png
# ├── 000074_camera2.png
# ├── 000074_camera3.png
# ├── 000074_gnss_imu.yaml
# ├── 000074_lidar.ply
# ├── 000074_semantic0.png
# ├── 000074_semantic1.png
# ├── 000074_semantic2.png
# ├── 000074_semantic3.png
# ├── 000075.yaml
# ├── 000075_camera0.png
# ├── 000075_camera1.png
# ├── 000075_camera2.png
# ├── 000075_camera3.png
# ├── 000075_gnss_imu.yaml
# ├── 000075_lidar.ply
# ├── 000075_semantic0.png
# ├── 000075_semantic1.png
# ├── 000075_semantic2.png
# ├── 000075_semantic3.png
# ├── 000076.yaml
# ├── 000076_camera0.png
# ├── 000076_camera1.png
# ├── 000076_camera2.png
# ├── 000076_camera3.png
# ├── 000076_gnss_imu.yaml
# ├── 000076_lidar.ply
# ├── 000076_semantic0.png
# ├── 000076_semantic1.png
# ├── 000076_semantic2.png
# ├── 000076_semantic3.png
# ├── 000077.yaml
# ├── 000077_camera0.png
# ├── 000077_camera1.png
# ├── 000077_camera2.png
# ├── 000077_camera3.png
# ├── 000077_gnss_imu.yaml
# ├── 000077_lidar.ply
# ├── 000077_semantic0.png
# ├── 000077_semantic1.png
# ├── 000077_semantic2.png
# ├── 000077_semantic3.png
# ├── 000078.yaml
# ├── 000078_camera0.png
# ├── 000078_camera1.png
# ├── 000078_camera2.png
# ├── 000078_camera3.png
# ├── 000078_gnss_imu.yaml
# ├── 000078_lidar.ply
# ├── 000078_semantic0.png
# ├── 000078_semantic1.png
# ├── 000078_semantic2.png
# ├── 000078_semantic3.png
# ├── 000079.yaml
# ├── 000079_camera0.png
# ├── 000079_camera1.png
# ├── 000079_camera2.png
# ├── 000079_camera3.png
# ├── 000079_gnss_imu.yaml
# ├── 000079_lidar.ply
# ├── 000079_semantic0.png
# ├── 000079_semantic1.png
# ├── 000079_semantic2.png
# ├── 000079_semantic3.png
# ├── 000080.yaml
# ├── 000080_camera0.png
# ├── 000080_camera1.png
# ├── 000080_camera2.png
# ├── 000080_camera3.png
# ├── 000080_gnss_imu.yaml
# ├── 000080_lidar.ply
# ├── 000080_semantic0.png
# ├── 000080_semantic2.png
# ├── 000080_semantic3.png
# ├── 000081.yaml
# ├── 000081_camera0.png
# ├── 000081_camera1.png
# ├── 000081_camera2.png
# ├── 000081_camera3.png
# ├── 000081_gnss_imu.yaml
# ├── 000081_lidar.ply
# ├── 000081_semantic0.png
# ├── 000081_semantic1.png
# ├── 000081_semantic2.png
# ├── 000081_semantic3.png
# ├── 000082.yaml
# ├── 000082_camera0.png
# ├── 000082_camera1.png
# ├── 000082_camera2.png
# ├── 000082_camera3.png
# ├── 000082_gnss_imu.yaml
# ├── 000082_lidar.ply
# ├── 000082_semantic0.png
# ├── 000082_semantic1.png
# ├── 000082_semantic2.png
# ├── 000082_semantic3.png
# ├── 000083.yaml
# ├── 000083_camera0.png
# ├── 000083_camera1.png
# ├── 000083_camera2.png
# ├── 000083_camera3.png
# ├── 000083_gnss_imu.yaml
# ├── 000083_lidar.ply
# ├── 000083_semantic0.png
# ├── 000083_semantic1.png
# ├── 000083_semantic2.png
# ├── 000083_semantic3.png
# ├── 000084.yaml
# ├── 000084_camera0.png
# ├── 000084_camera1.png
# ├── 000084_camera2.png
# ├── 000084_camera3.png
# ├── 000084_gnss_imu.yaml
# ├── 000084_lidar.ply
# ├── 000084_semantic0.png
# ├── 000084_semantic1.png
# ├── 000084_semantic2.png
# ├── 000084_semantic3.png
# ├── 000085.yaml
# ├── 000085_camera0.png
# ├── 000085_camera1.png
# ├── 000085_camera2.png
# ├── 000085_camera3.png
# ├── 000085_gnss_imu.yaml
# ├── 000085_lidar.ply
# ├── 000085_semantic0.png
# ├── 000085_semantic1.png
# ├── 000085_semantic2.png
# ├── 000085_semantic3.png
# ├── 000086.yaml
# ├── 000086_camera0.png
# ├── 000086_camera1.png
# ├── 000086_camera2.png
# ├── 000086_camera3.png
# ├── 000086_gnss_imu.yaml
# ├── 000086_lidar.ply
# ├── 000086_semantic0.png
# ├── 000087.yaml
# ├── 000087_camera0.png
# ├── 000087_camera1.png
# ├── 000087_camera2.png
# ├── 000087_camera3.png
# ├── 000087_gnss_imu.yaml
# ├── 000087_lidar.ply
# ├── 000087_semantic0.png
# ├── 000087_semantic1.png
# ├── 000087_semantic2.png
# ├── 000087_semantic3.png
# ├── 000088.yaml
# ├── 000088_camera0.png
# ├── 000088_camera1.png
# ├── 000088_camera2.png
# ├── 000088_camera3.png
# ├── 000088_gnss_imu.yaml
# ├── 000088_lidar.ply
# ├── 000088_semantic0.png
# ├── 000088_semantic1.png
# ├── 000088_semantic2.png
# ├── 000088_semantic3.png
# ├── 000089.yaml
# ├── 000089_camera0.png
# ├── 000089_camera1.png
# ├── 000089_camera2.png
# ├── 000089_camera3.png
# ├── 000089_gnss_imu.yaml
# ├── 000089_lidar.ply
# ├── 000089_semantic0.png
# ├── 000089_semantic2.png
# ├── 000089_semantic3.png
# ├── 000090.yaml
# ├── 000090_camera0.png
# ├── 000090_camera1.png
# ├── 000090_camera2.png
# ├── 000090_camera3.png
# ├── 000090_gnss_imu.yaml
# ├── 000090_lidar.ply
# ├── 000090_semantic0.png
# ├── 000090_semantic1.png
# ├── 000090_semantic2.png
# ├── 000090_semantic3.png
# ├── 000091.yaml
# ├── 000091_camera0.png
# ├── 000091_camera1.png
# ├── 000091_camera2.png
# ├── 000091_camera3.png
# ├── 000091_gnss_imu.yaml
# ├── 000091_lidar.ply
# ├── 000091_semantic0.png
# ├── 000091_semantic1.png
# ├── 000091_semantic2.png
# ├── 000091_semantic3.png
# ├── 000092.yaml
# ├── 000092_camera0.png
# ├── 000092_camera1.png
# ├── 000092_camera2.png
# ├── 000092_camera3.png
# ├── 000092_gnss_imu.yaml
# ├── 000092_lidar.ply
# ├── 000092_semantic0.png
# ├── 000092_semantic1.png
# ├── 000092_semantic2.png
# ├── 000092_semantic3.png
# ├── 000093.yaml
# ├── 000093_camera0.png
# ├── 000093_camera1.png
# ├── 000093_camera2.png
# ├── 000093_camera3.png
# ├── 000093_gnss_imu.yaml
# ├── 000093_lidar.ply
# ├── 000093_semantic0.png
# ├── 000093_semantic1.png
# ├── 000093_semantic2.png
# ├── 000093_semantic3.png
# ├── 000094.yaml
# ├── 000094_camera0.png
# ├── 000094_camera1.png
# ├── 000094_camera2.png
# ├── 000094_camera3.png
# ├── 000094_gnss_imu.yaml
# ├── 000094_lidar.ply
# ├── 000094_semantic0.png
# ├── 000094_semantic1.png
# ├── 000094_semantic2.png
# ├── 000094_semantic3.png
# ├── 000095.yaml
# ├── 000095_camera0.png
# ├── 000095_camera1.png
# ├── 000095_camera2.png
# ├── 000095_camera3.png
# ├── 000095_gnss_imu.yaml
# ├── 000095_lidar.ply
# ├── 000095_semantic0.png
# ├── 000095_semantic3.png
# ├── 000096.yaml
# ├── 000096_camera0.png
# ├── 000096_camera1.png
# ├── 000096_camera2.png
# ├── 000096_camera3.png
# ├── 000096_gnss_imu.yaml
# ├── 000096_lidar.ply
# ├── 000096_semantic0.png
# ├── 000096_semantic1.png
# ├── 000096_semantic2.png
# ├── 000097.yaml
# ├── 000097_camera0.png
# ├── 000097_camera1.png
# ├── 000097_camera2.png
# ├── 000097_camera3.png
# ├── 000097_gnss_imu.yaml
# ├── 000097_lidar.ply
# ├── 000097_semantic0.png
# ├── 000097_semantic1.png
# ├── 000097_semantic2.png
# ├── 000097_semantic3.png
# ├── 000098.yaml
# ├── 000098_camera0.png
# ├── 000098_camera1.png
# ├── 000098_camera2.png
# ├── 000098_camera3.png
# ├── 000098_gnss_imu.yaml
# ├── 000098_lidar.ply
# ├── 000098_semantic0.png
# ├── 000098_semantic1.png
# ├── 000098_semantic2.png
# ├── 000098_semantic3.png
# ├── 000099.yaml
# ├── 000099_camera0.png
# ├── 000099_camera1.png
# ├── 000099_camera2.png
# ├── 000099_camera3.png
# ├── 000099_gnss_imu.yaml
# ├── 000099_lidar.ply
# ├── 000099_semantic0.png
# ├── 000099_semantic1.png
# ├── 000099_semantic2.png
# ├── 000099_semantic3.png
# ├── 000100.yaml
# ├── 000100_camera0.png
# ├── 000100_camera1.png
# ├── 000100_camera2.png
# ├── 000100_camera3.png
# ├── 000100_gnss_imu.yaml
# ├── 000100_lidar.ply
# ├── 000100_semantic0.png
# ├── 000100_semantic1.png
# ├── 000100_semantic2.png
# ├── 000100_semantic3.png
# ├── 000101.yaml
# ├── 000101_camera0.png
# ├── 000101_camera1.png
# ├── 000101_camera2.png
# ├── 000101_camera3.png
# ├── 000101_gnss_imu.yaml
# ├── 000101_lidar.ply
# ├── 000101_semantic0.png
# ├── 000101_semantic1.png
# ├── 000101_semantic2.png
# ├── 000101_semantic3.png
# ├── 000102.yaml
# ├── 000102_camera0.png
# ├── 000102_camera1.png
# ├── 000102_camera2.png
# ├── 000102_camera3.png
# ├── 000102_gnss_imu.yaml
# ├── 000102_lidar.ply
# ├── 000102_semantic0.png
# ├── 000102_semantic1.png
# ├── 000102_semantic2.png
# ├── 000102_semantic3.png
# ├── 000103.yaml
# ├── 000103_camera0.png
# ├── 000103_camera1.png
# ├── 000103_camera2.png
# ├── 000103_camera3.png
# ├── 000103_gnss_imu.yaml
# ├── 000103_lidar.ply
# ├── 000103_semantic0.png
# ├── 000103_semantic1.png
# ├── 000103_semantic2.png
# ├── 000103_semantic3.png
# ├── 000104.yaml
# ├── 000104_camera0.png
# ├── 000104_camera1.png
# ├── 000104_camera2.png
# ├── 000104_camera3.png
# ├── 000104_gnss_imu.yaml
# ├── 000104_lidar.ply
# ├── 000104_semantic0.png
# ├── 000104_semantic1.png
# ├── 000104_semantic2.png
# ├── 000104_semantic3.png
# ├── 000105.yaml
# ├── 000105_camera0.png
# ├── 000105_camera1.png
# ├── 000105_camera2.png
# ├── 000105_camera3.png
# ├── 000105_gnss_imu.yaml
# ├── 000105_lidar.ply
# ├── 000105_semantic0.png
# ├── 000105_semantic1.png
# ├── 000105_semantic2.png
# ├── 000105_semantic3.png
# ├── 000106.yaml
# ├── 000106_camera0.png
# ├── 000106_camera1.png
# ├── 000106_camera2.png
# ├── 000106_camera3.png
# ├── 000106_gnss_imu.yaml
# ├── 000106_lidar.ply
# ├── 000106_semantic0.png
# ├── 000106_semantic1.png
# ├── 000106_semantic2.png
# ├── 000106_semantic3.png
# ├── 000107.yaml
# ├── 000107_camera0.png
# ├── 000107_camera1.png
# ├── 000107_camera2.png
# ├── 000107_camera3.png
# ├── 000107_gnss_imu.yaml
# ├── 000107_lidar.ply
# ├── 000107_semantic0.png
# ├── 000107_semantic1.png
# ├── 000107_semantic2.png
# ├── 000107_semantic3.png
# ├── 000108.yaml
# ├── 000108_camera0.png
# ├── 000108_camera1.png
# ├── 000108_camera2.png
# ├── 000108_camera3.png
# ├── 000108_gnss_imu.yaml
# ├── 000108_lidar.ply
# ├── 000108_semantic0.png
# ├── 000109.yaml
# ├── 000109_camera0.png
# ├── 000109_camera1.png
# ├── 000109_camera2.png
# ├── 000109_camera3.png
# ├── 000109_gnss_imu.yaml
# ├── 000109_lidar.ply
# ├── 000109_semantic0.png
# ├── 000109_semantic1.png
# ├── 000109_semantic2.png
# ├── 000109_semantic3.png
# ├── 000110.yaml
# ├── 000110_camera0.png
# ├── 000110_camera1.png
# ├── 000110_camera2.png
# ├── 000110_camera3.png
# ├── 000110_gnss_imu.yaml
# ├── 000110_lidar.ply
# ├── 000110_semantic0.png
# ├── 000110_semantic1.png
# ├── 000110_semantic2.png
# ├── 000110_semantic3.png
# ├── 000111.yaml
# ├── 000111_camera0.png
# ├── 000111_camera1.png
# ├── 000111_camera2.png
# ├── 000111_camera3.png
# ├── 000111_gnss_imu.yaml
# ├── 000111_lidar.ply
# ├── 000111_semantic0.png
# ├── 000111_semantic1.png
# ├── 000111_semantic2.png
# ├── 000111_semantic3.png
# ├── 000112.yaml
# ├── 000112_camera0.png
# ├── 000112_camera1.png
# ├── 000112_camera2.png
# ├── 000112_camera3.png
# ├── 000112_gnss_imu.yaml
# ├── 000112_lidar.ply
# ├── 000112_semantic1.png
# ├── 000112_semantic2.png
# ├── 000112_semantic3.png
# ├── 000113.yaml
# ├── 000113_camera0.png
# ├── 000113_camera1.png
# ├── 000113_camera2.png
# ├── 000113_camera3.png
# ├── 000113_gnss_imu.yaml
# ├── 000113_lidar.ply
# ├── 000113_semantic0.png
# ├── 000113_semantic3.png
# ├── 000114.yaml
# ├── 000114_camera0.png
# ├── 000114_camera1.png
# ├── 000114_camera2.png
# ├── 000114_camera3.png
# ├── 000114_gnss_imu.yaml
# ├── 000114_lidar.ply
# ├── 000114_semantic0.png
# ├── 000114_semantic1.png
# ├── 000114_semantic2.png
# ├── 000114_semantic3.png
# ├── 000115.yaml
# ├── 000115_camera0.png
# ├── 000115_camera1.png
# ├── 000115_camera2.png
# ├── 000115_camera3.png
# ├── 000115_gnss_imu.yaml
# ├── 000115_lidar.ply
# ├── 000115_semantic0.png
# ├── 000115_semantic1.png
# ├── 000115_semantic2.png
# ├── 000115_semantic3.png
# ├── 000116.yaml
# ├── 000116_camera0.png
# ├── 000116_camera1.png
# ├── 000116_camera2.png
# ├── 000116_camera3.png
# ├── 000116_gnss_imu.yaml
# ├── 000116_lidar.ply
# ├── 000116_semantic0.png
# ├── 000116_semantic1.png
# ├── 000116_semantic2.png
# ├── 000116_semantic3.png
# ├── 000117.yaml
# ├── 000117_camera0.png
# ├── 000117_camera1.png
# ├── 000117_camera2.png
# ├── 000117_camera3.png
# ├── 000117_gnss_imu.yaml
# ├── 000117_lidar.ply
# ├── 000117_semantic0.png
# ├── 000117_semantic1.png
# ├── 000117_semantic2.png
# ├── 000117_semantic3.png
# ├── 000118.yaml
# ├── 000118_camera0.png
# ├── 000118_camera1.png
# ├── 000118_camera2.png
# ├── 000118_camera3.png
# ├── 000118_gnss_imu.yaml
# ├── 000118_lidar.ply
# ├── 000118_semantic0.png
# ├── 000118_semantic1.png
# ├── 000118_semantic2.png
# ├── 000118_semantic3.png
# ├── 000119.yaml
# ├── 000119_camera0.png
# ├── 000119_camera1.png
# ├── 000119_camera2.png
# ├── 000119_camera3.png
# ├── 000119_gnss_imu.yaml
# ├── 000119_lidar.ply
# ├── 000119_semantic0.png
# ├── 000119_semantic1.png
# ├── 000119_semantic2.png
# ├── 000119_semantic3.png
# ├── 000120.yaml
# ├── 000120_camera0.png
# ├── 000120_camera1.png
# ├── 000120_camera2.png
# ├── 000120_camera3.png
# ├── 000120_gnss_imu.yaml
# ├── 000120_lidar.ply
# ├── 000120_semantic0.png
# ├── 000121.yaml
# ├── 000121_camera0.png
# ├── 000121_camera1.png
# ├── 000121_camera2.png
# ├── 000121_camera3.png
# ├── 000121_gnss_imu.yaml
# ├── 000121_lidar.ply
# ├── 000121_semantic0.png
# ├── 000121_semantic1.png
# ├── 000121_semantic2.png
# ├── 000121_semantic3.png
# ├── 000122.yaml
# ├── 000122_camera0.png
# ├── 000122_camera1.png
# ├── 000122_camera2.png
# ├── 000122_camera3.png
# ├── 000122_gnss_imu.yaml
# ├── 000122_lidar.ply
# ├── 000122_semantic0.png
# ├── 000122_semantic1.png
# ├── 000122_semantic2.png
# ├── 000122_semantic3.png
# ├── 000123.yaml
# ├── 000123_camera0.png
# ├── 000123_camera1.png
# ├── 000123_camera2.png
# ├── 000123_camera3.png
# ├── 000123_gnss_imu.yaml
# ├── 000123_lidar.ply
# ├── 000123_semantic0.png
# ├── 000123_semantic1.png
# ├── 000123_semantic2.png
# ├── 000123_semantic3.png
# ├── 000124.yaml
# ├── 000124_camera0.png
# ├── 000124_camera1.png
# ├── 000124_camera2.png
# ├── 000124_camera3.png
# ├── 000124_gnss_imu.yaml
# ├── 000124_lidar.ply
# ├── 000124_semantic0.png
# ├── 000124_semantic1.png
# ├── 000124_semantic2.png
# ├── 000124_semantic3.png
# ├── 000125.yaml
# ├── 000125_camera0.png
# ├── 000125_camera1.png
# ├── 000125_camera2.png
# ├── 000125_camera3.png
# ├── 000125_gnss_imu.yaml
# ├── 000125_lidar.ply
# ├── 000125_semantic0.png
# ├── 000125_semantic1.png
# ├── 000125_semantic2.png
# ├── 000125_semantic3.png
# ├── 000126.yaml
# ├── 000126_camera0.png
# ├── 000126_camera1.png
# ├── 000126_camera2.png
# ├── 000126_camera3.png
# ├── 000126_gnss_imu.yaml
# ├── 000126_lidar.ply
# ├── 000126_semantic0.png
# ├── 000126_semantic1.png
# ├── 000126_semantic2.png
# ├── 000126_semantic3.png
# ├── 000127.yaml
# ├── 000127_camera0.png
# ├── 000127_camera1.png
# ├── 000127_camera2.png
# ├── 000127_camera3.png
# ├── 000127_gnss_imu.yaml
# ├── 000127_lidar.ply
# ├── 000127_semantic0.png
# ├── 000127_semantic1.png
# ├── 000127_semantic2.png
# ├── 000127_semantic3.png
# ├── 000128.yaml
# ├── 000128_camera0.png
# ├── 000128_camera1.png
# ├── 000128_camera2.png
# ├── 000128_camera3.png
# ├── 000128_gnss_imu.yaml
# ├── 000128_lidar.ply
# ├── 000128_semantic0.png
# ├── 000128_semantic3.png
# ├── 000129.yaml
# ├── 000129_camera0.png
# ├── 000129_camera1.png
# ├── 000129_camera2.png
# ├── 000129_camera3.png
# ├── 000129_gnss_imu.yaml
# ├── 000129_lidar.ply
# ├── 000129_semantic0.png
# ├── 000129_semantic1.png
# ├── 000129_semantic2.png
# ├── 000129_semantic3.png
# ├── 000130.yaml
# ├── 000130_camera0.png
# ├── 000130_camera1.png
# ├── 000130_camera2.png
# ├── 000130_camera3.png
# ├── 000130_gnss_imu.yaml
# ├── 000130_lidar.ply
# ├── 000130_semantic0.png
# ├── 000130_semantic1.png
# ├── 000130_semantic2.png
# ├── 000130_semantic3.png
# ├── 000131.yaml
# ├── 000131_camera0.png
# ├── 000131_camera1.png
# ├── 000131_camera2.png
# ├── 000131_camera3.png
# ├── 000131_gnss_imu.yaml
# ├── 000131_lidar.ply
# ├── 000131_semantic0.png
# ├── 000131_semantic1.png
# ├── 000131_semantic2.png
# ├── 000131_semantic3.png
# ├── 000132.yaml
# ├── 000132_camera0.png
# ├── 000132_camera1.png
# ├── 000132_camera2.png
# ├── 000132_camera3.png
# ├── 000132_gnss_imu.yaml
# ├── 000132_lidar.ply
# ├── 000132_semantic0.png
# ├── 000133.yaml
# ├── 000133_camera0.png
# ├── 000133_camera1.png
# ├── 000133_camera2.png
# ├── 000133_camera3.png
# ├── 000133_gnss_imu.yaml
# ├── 000133_lidar.ply
# ├── 000133_semantic0.png
# ├── 000133_semantic1.png
# ├── 000133_semantic2.png
# ├── 000133_semantic3.png
# ├── 000134.yaml
# ├── 000134_camera0.png
# ├── 000134_camera1.png
# ├── 000134_camera2.png
# ├── 000134_camera3.png
# ├── 000134_gnss_imu.yaml
# ├── 000134_lidar.ply
# ├── 000134_semantic0.png
# ├── 000134_semantic1.png
# ├── 000134_semantic2.png
# ├── 000134_semantic3.png
# ├── 000135.yaml
# ├── 000135_camera0.png
# ├── 000135_camera1.png
# ├── 000135_camera2.png
# ├── 000135_camera3.png
# ├── 000135_gnss_imu.yaml
# ├── 000135_lidar.ply
# ├── 000135_semantic0.png
# ├── 000135_semantic1.png
# ├── 000135_semantic2.png
# ├── 000135_semantic3.png
# ├── 000136.yaml
# ├── 000136_camera0.png
# ├── 000136_camera1.png
# ├── 000136_camera2.png
# ├── 000136_camera3.png
# ├── 000136_gnss_imu.yaml
# ├── 000136_lidar.ply
# ├── 000136_semantic0.png
# ├── 000136_semantic1.png
# ├── 000136_semantic2.png
# ├── 000136_semantic3.png
# ├── 000137.yaml
# ├── 000137_camera0.png
# ├── 000137_camera1.png
# ├── 000137_camera2.png
# ├── 000137_camera3.png
# ├── 000137_gnss_imu.yaml
# ├── 000137_lidar.ply
# ├── 000137_semantic0.png
# ├── 000137_semantic1.png
# ├── 000137_semantic2.png
# ├── 000137_semantic3.png
# ├── 000138.yaml
# ├── 000138_camera0.png
# ├── 000138_camera1.png
# ├── 000138_camera2.png
# ├── 000138_camera3.png
# ├── 000138_gnss_imu.yaml
# ├── 000138_lidar.ply
# ├── 000138_semantic0.png
# ├── 000138_semantic1.png
# ├── 000138_semantic2.png
# ├── 000138_semantic3.png
# ├── 000139.yaml
# ├── 000139_camera0.png
# ├── 000139_camera1.png
# ├── 000139_camera2.png
# ├── 000139_camera3.png
# ├── 000139_gnss_imu.yaml
# ├── 000139_lidar.ply
# ├── 000139_semantic0.png
# ├── 000139_semantic1.png
# ├── 000139_semantic2.png
# ├── 000139_semantic3.png
# ├── 000140.yaml
# ├── 000140_camera0.png
# ├── 000140_camera1.png
# ├── 000140_camera2.png
# ├── 000140_camera3.png
# ├── 000140_gnss_imu.yaml
# ├── 000140_lidar.ply
# ├── 000140_semantic0.png
# ├── 000140_semantic2.png
# ├── 000140_semantic3.png
# ├── 000141.yaml
# ├── 000141_camera0.png
# ├── 000141_camera1.png
# ├── 000141_camera2.png
# ├── 000141_camera3.png
# ├── 000141_gnss_imu.yaml
# ├── 000141_lidar.ply
# ├── 000141_semantic0.png
# ├── 000141_semantic1.png
# ├── 000142.yaml
# ├── 000142_camera0.png
# ├── 000142_camera1.png
# ├── 000142_camera2.png
# ├── 000142_camera3.png
# ├── 000142_gnss_imu.yaml
# ├── 000142_lidar.ply
# ├── 000142_semantic0.png
# ├── 000142_semantic1.png
# ├── 000142_semantic2.png
# ├── 000142_semantic3.png
# ├── 000143.yaml
# ├── 000143_camera0.png
# ├── 000143_camera1.png
# ├── 000143_camera2.png
# ├── 000143_camera3.png
# ├── 000143_gnss_imu.yaml
# ├── 000143_lidar.ply
# ├── 000143_semantic0.png
# ├── 000143_semantic2.png
# ├── 000143_semantic3.png
# ├── 000144.yaml
# ├── 000144_camera0.png
# ├── 000144_camera1.png
# ├── 000144_camera2.png
# ├── 000144_camera3.png
# ├── 000144_gnss_imu.yaml
# ├── 000144_lidar.ply
# ├── 000144_semantic0.png
# ├── 000144_semantic1.png
# ├── 000145.yaml
# ├── 000145_camera0.png
# ├── 000145_camera1.png
# ├── 000145_camera2.png
# ├── 000145_camera3.png
# ├── 000145_gnss_imu.yaml
# ├── 000145_lidar.ply
# ├── 000145_semantic0.png
# ├── 000145_semantic1.png
# ├── 000145_semantic2.png
# ├── 000145_semantic3.png
# ├── 000146.yaml
# ├── 000146_camera0.png
# ├── 000146_camera1.png
# ├── 000146_camera2.png
# ├── 000146_camera3.png
# ├── 000146_gnss_imu.yaml
# ├── 000146_lidar.ply
# ├── 000146_semantic0.png
# ├── 000146_semantic1.png
# ├── 000146_semantic2.png
# ├── 000146_semantic3.png
# ├── 000147.yaml
# ├── 000147_camera0.png
# ├── 000147_camera1.png
# ├── 000147_camera2.png
# ├── 000147_camera3.png
# ├── 000147_gnss_imu.yaml
# ├── 000147_lidar.ply
# ├── 000147_semantic0.png
# ├── 000147_semantic1.png
# ├── 000147_semantic2.png
# ├── 000147_semantic3.png
# ├── 000148.yaml
# ├── 000148_camera0.png
# ├── 000148_camera1.png
# ├── 000148_camera2.png
# ├── 000148_camera3.png
# ├── 000148_gnss_imu.yaml
# ├── 000148_lidar.ply
# ├── 000148_semantic0.png
# ├── 000148_semantic1.png
# ├── 000148_semantic2.png
# ├── 000148_semantic3.png
# ├── 000149.yaml
# ├── 000149_camera0.png
# ├── 000149_camera1.png
# ├── 000149_camera2.png
# ├── 000149_camera3.png
# ├── 000149_gnss_imu.yaml
# ├── 000149_lidar.ply
# ├── 000149_semantic0.png
# ├── 000149_semantic1.png
# ├── 000149_semantic2.png
# ├── 000149_semantic3.png
# ├── 000150.yaml
# ├── 000150_camera0.png
# ├── 000150_camera1.png
# ├── 000150_camera2.png
# ├── 000150_camera3.png
# ├── 000150_gnss_imu.yaml
# ├── 000150_lidar.ply
# ├── 000150_semantic0.png
# ├── 000150_semantic2.png
# ├── 000150_semantic3.png
# ├── 000151.yaml
# ├── 000151_camera0.png
# ├── 000151_camera1.png
# ├── 000151_camera2.png
# ├── 000151_camera3.png
# ├── 000151_gnss_imu.yaml
# ├── 000151_lidar.ply
# ├── 000151_semantic0.png
# ├── 000151_semantic1.png
# ├── 000151_semantic2.png
# ├── 000151_semantic3.png
# ├── 000152.yaml
# ├── 000152_camera0.png
# ├── 000152_camera1.png
# ├── 000152_camera2.png
# ├── 000152_camera3.png
# ├── 000152_gnss_imu.yaml
# ├── 000152_lidar.ply
# ├── 000152_semantic0.png
# ├── 000152_semantic1.png
# ├── 000152_semantic2.png
# ├── 000152_semantic3.png
# ├── 000153.yaml
# ├── 000153_camera0.png
# ├── 000153_camera1.png
# ├── 000153_camera2.png
# ├── 000153_camera3.png
# ├── 000153_gnss_imu.yaml
# ├── 000153_lidar.ply
# ├── 000153_semantic0.png
# ├── 000153_semantic1.png
# ├── 000153_semantic2.png
# ├── 000153_semantic3.png
# ├── 000154.yaml
# ├── 000154_camera0.png
# ├── 000154_camera1.png
# ├── 000154_camera2.png
# ├── 000154_camera3.png
# ├── 000154_gnss_imu.yaml
# ├── 000154_lidar.ply
# ├── 000154_semantic0.png
# ├── 000155.yaml
# ├── 000155_camera0.png
# ├── 000155_camera1.png
# ├── 000155_camera2.png
# ├── 000155_camera3.png
# ├── 000155_gnss_imu.yaml
# ├── 000155_lidar.ply
# ├── 000155_semantic0.png
# ├── 000155_semantic1.png
# ├── 000155_semantic2.png
# ├── 000155_semantic3.png
# ├── 000156.yaml
# ├── 000156_camera0.png
# ├── 000156_camera1.png
# ├── 000156_camera2.png
# ├── 000156_camera3.png
# ├── 000156_gnss_imu.yaml
# ├── 000156_lidar.ply
# ├── 000156_semantic0.png
# ├── 000156_semantic1.png
# ├── 000156_semantic2.png
# ├── 000156_semantic3.png
# ├── 000157.yaml
# ├── 000157_camera0.png
# ├── 000157_camera1.png
# ├── 000157_camera2.png
# ├── 000157_camera3.png
# ├── 000157_gnss_imu.yaml
# ├── 000157_lidar.ply
# ├── 000157_semantic0.png
# ├── 000157_semantic1.png
# ├── 000157_semantic2.png
# ├── 000157_semantic3.png
# ├── 000158.yaml
# ├── 000158_camera0.png
# ├── 000158_camera1.png
# ├── 000158_camera2.png
# ├── 000158_camera3.png
# ├── 000158_gnss_imu.yaml
# ├── 000158_lidar.ply
# ├── 000158_semantic0.png
# ├── 000158_semantic1.png
# ├── 000158_semantic2.png
# ├── 000158_semantic3.png
# ├── 000159.yaml
# ├── 000159_camera0.png
# ├── 000159_camera1.png
# ├── 000159_camera2.png
# ├── 000159_camera3.png
# ├── 000159_gnss_imu.yaml
# ├── 000159_lidar.ply
# ├── 000159_semantic0.png
# ├── 000159_semantic1.png
# ├── 000159_semantic2.png
# ├── 000159_semantic3.png
# ├── 000160.yaml
# ├── 000160_camera0.png
# ├── 000160_camera1.png
# ├── 000160_camera2.png
# ├── 000160_camera3.png
# ├── 000160_gnss_imu.yaml
# ├── 000160_lidar.ply
# ├── 000160_semantic0.png
# ├── 000160_semantic1.png
# ├── 000160_semantic2.png
# ├── 000160_semantic3.png
# ├── 000161.yaml
# ├── 000161_camera0.png
# ├── 000161_camera1.png
# ├── 000161_camera2.png
# ├── 000161_camera3.png
# ├── 000161_gnss_imu.yaml
# ├── 000161_lidar.ply
# ├── 000161_semantic0.png
# ├── 000162.yaml
# ├── 000162_camera0.png
# ├── 000162_camera1.png
# ├── 000162_camera2.png
# ├── 000162_camera3.png
# ├── 000162_gnss_imu.yaml
# ├── 000162_lidar.ply
# ├── 000162_semantic0.png
# ├── 000162_semantic1.png
# ├── 000162_semantic2.png
# ├── 000162_semantic3.png
# ├── 000163.yaml
# ├── 000163_camera0.png
# ├── 000163_camera1.png
# ├── 000163_camera2.png
# ├── 000163_camera3.png
# ├── 000163_gnss_imu.yaml
# ├── 000163_lidar.ply
# ├── 000163_semantic0.png
# ├── 000163_semantic1.png
# ├── 000163_semantic2.png
# ├── 000163_semantic3.png
# ├── 000164.yaml
# ├── 000164_camera0.png
# ├── 000164_camera1.png
# ├── 000164_camera2.png
# ├── 000164_camera3.png
# ├── 000164_gnss_imu.yaml
# ├── 000164_lidar.ply
# ├── 000164_semantic0.png
# ├── 000165.yaml
# ├── 000165_camera0.png
# ├── 000165_camera1.png
# ├── 000165_camera2.png
# ├── 000165_camera3.png
# ├── 000165_gnss_imu.yaml
# ├── 000165_lidar.ply
# ├── 000165_semantic0.png
# ├── 000165_semantic1.png
# ├── 000165_semantic2.png
# ├── 000165_semantic3.png
# ├── 000166.yaml
# ├── 000166_camera0.png
# ├── 000166_camera1.png
# ├── 000166_camera2.png
# ├── 000166_camera3.png
# ├── 000166_gnss_imu.yaml
# ├── 000166_lidar.ply
# ├── 000166_semantic0.png
# ├── 000166_semantic1.png
# ├── 000166_semantic2.png
# ├── 000166_semantic3.png
# ├── 000167.yaml
# ├── 000167_camera0.png
# ├── 000167_camera1.png
# ├── 000167_camera2.png
# ├── 000167_camera3.png
# ├── 000167_gnss_imu.yaml
# ├── 000167_lidar.ply
# ├── 000167_semantic0.png
# ├── 000167_semantic1.png
# ├── 000167_semantic2.png
# ├── 000167_semantic3.png
# ├── 000168.yaml
# ├── 000168_camera0.png
# ├── 000168_camera1.png
# ├── 000168_camera2.png
# ├── 000168_camera3.png
# ├── 000168_gnss_imu.yaml
# ├── 000168_lidar.ply
# ├── 000168_semantic0.png
# ├── 000168_semantic1.png
# ├── 000168_semantic2.png
# ├── 000168_semantic3.png
# ├── 000169.yaml
# ├── 000169_camera0.png
# ├── 000169_camera1.png
# ├── 000169_camera2.png
# ├── 000169_camera3.png
# ├── 000169_gnss_imu.yaml
# ├── 000169_lidar.ply
# ├── 000169_semantic0.png
# ├── 000169_semantic1.png
# ├── 000169_semantic2.png
# ├── 000169_semantic3.png
# ├── 000170.yaml
# ├── 000170_camera0.png
# ├── 000170_camera1.png
# ├── 000170_camera2.png
# ├── 000170_camera3.png
# ├── 000170_gnss_imu.yaml
# ├── 000170_lidar.ply
# ├── 000170_semantic0.png
# ├── 000170_semantic1.png
# ├── 000170_semantic2.png
# ├── 000170_semantic3.png
# ├── 000171.yaml
# ├── 000171_camera0.png
# ├── 000171_camera1.png
# ├── 000171_camera2.png
# ├── 000171_camera3.png
# ├── 000171_gnss_imu.yaml
# ├── 000171_lidar.ply
# ├── 000171_semantic0.png
# ├── 000171_semantic1.png
# ├── 000171_semantic2.png
# ├── 000171_semantic3.png
# ├── 000172.yaml
# ├── 000172_camera0.png
# ├── 000172_camera1.png
# ├── 000172_camera2.png
# ├── 000172_camera3.png
# ├── 000172_gnss_imu.yaml
# ├── 000172_lidar.ply
# ├── 000172_semantic0.png
# ├── 000173.yaml
# ├── 000173_camera0.png
# ├── 000173_camera1.png
# ├── 000173_camera2.png
# ├── 000173_camera3.png
# ├── 000173_gnss_imu.yaml
# ├── 000173_lidar.ply
# ├── 000173_semantic0.png
# ├── 000173_semantic1.png
# ├── 000173_semantic2.png
# ├── 000173_semantic3.png
# ├── 000174.yaml
# ├── 000174_camera0.png
# ├── 000174_camera1.png
# ├── 000174_camera2.png
# ├── 000174_camera3.png
# ├── 000174_gnss_imu.yaml
# ├── 000174_lidar.ply
# ├── 000174_semantic0.png
# ├── 000174_semantic1.png
# ├── 000174_semantic2.png
# ├── 000174_semantic3.png
# ├── 000175.yaml
# ├── 000175_camera0.png
# ├── 000175_camera1.png
# ├── 000175_camera2.png
# ├── 000175_camera3.png
# ├── 000175_gnss_imu.yaml
# ├── 000175_lidar.ply
# ├── 000175_semantic0.png
# ├── 000175_semantic1.png
# ├── 000175_semantic2.png
# ├── 000175_semantic3.png
# ├── 000176.yaml
# ├── 000176_camera0.png
# ├── 000176_camera1.png
# ├── 000176_camera2.png
# ├── 000176_camera3.png
# ├── 000176_gnss_imu.yaml
# ├── 000176_lidar.ply
# ├── 000176_semantic0.png
# ├── 000176_semantic1.png
# ├── 000176_semantic2.png
# ├── 000176_semantic3.png
# ├── 000177.yaml
# ├── 000177_camera0.png
# ├── 000177_camera1.png
# ├── 000177_camera2.png
# ├── 000177_camera3.png
# ├── 000177_gnss_imu.yaml
# ├── 000177_lidar.ply
# ├── 000177_semantic0.png
# ├── 000177_semantic1.png
# ├── 000177_semantic2.png
# ├── 000177_semantic3.png
# ├── 000178.yaml
# ├── 000178_camera0.png
# ├── 000178_camera1.png
# ├── 000178_camera2.png
# ├── 000178_camera3.png
# ├── 000178_gnss_imu.yaml
# ├── 000178_lidar.ply
# ├── 000178_semantic0.png
# ├── 000178_semantic1.png
# ├── 000178_semantic2.png
# ├── 000178_semantic3.png
# ├── 000179.yaml
# ├── 000179_camera0.png
# ├── 000179_camera1.png
# ├── 000179_camera2.png
# ├── 000179_camera3.png
# ├── 000179_gnss_imu.yaml
# ├── 000179_lidar.ply
# ├── 000179_semantic0.png
# ├── 000179_semantic1.png
# ├── 000179_semantic2.png
# ├── 000179_semantic3.png
# ├── 000180.yaml
# ├── 000180_camera0.png
# ├── 000180_camera1.png
# ├── 000180_camera2.png
# ├── 000180_camera3.png
# ├── 000180_gnss_imu.yaml
# ├── 000180_lidar.ply
# ├── 000180_semantic0.png
# ├── 000180_semantic1.png
# ├── 000180_semantic2.png
# ├── 000180_semantic3.png
# ├── 000181.yaml
# ├── 000181_camera0.png
# ├── 000181_camera1.png
# ├── 000181_camera2.png
# ├── 000181_camera3.png
# ├── 000181_gnss_imu.yaml
# ├── 000181_lidar.ply
# ├── 000181_semantic0.png
# ├── 000181_semantic1.png
# ├── 000181_semantic2.png
# ├── 000181_semantic3.png
# ├── 000182.yaml
# ├── 000182_camera0.png
# ├── 000182_camera1.png
# ├── 000182_camera2.png
# ├── 000182_camera3.png
# ├── 000182_gnss_imu.yaml
# ├── 000182_lidar.ply
# ├── 000182_semantic0.png
# ├── 000182_semantic1.png
# ├── 000182_semantic2.png
# ├── 000182_semantic3.png
# ├── 000183.yaml
# ├── 000183_camera0.png
# ├── 000183_camera1.png
# ├── 000183_camera2.png
# ├── 000183_camera3.png
# ├── 000183_gnss_imu.yaml
# ├── 000183_lidar.ply
# ├── 000183_semantic0.png
# ├── 000183_semantic1.png
# ├── 000183_semantic2.png
# ├── 000183_semantic3.png
# ├── 000184.yaml
# ├── 000184_camera0.png
# ├── 000184_camera1.png
# ├── 000184_camera2.png
# ├── 000184_camera3.png
# ├── 000184_gnss_imu.yaml
# ├── 000184_lidar.ply
# ├── 000185.yaml
# ├── 000185_camera0.png
# ├── 000185_camera1.png
# ├── 000185_camera2.png
# ├── 000185_camera3.png
# ├── 000185_gnss_imu.yaml
# ├── 000185_lidar.ply
# ├── 000185_semantic0.png
# ├── 000185_semantic1.png
# ├── 000185_semantic2.png
# ├── 000185_semantic3.png
# ├── 000186.yaml
# ├── 000186_camera0.png
# ├── 000186_camera1.png
# ├── 000186_camera2.png
# ├── 000186_camera3.png
# ├── 000186_gnss_imu.yaml
# ├── 000186_lidar.ply
# ├── 000186_semantic0.png
# ├── 000186_semantic1.png
# ├── 000186_semantic2.png
# ├── 000186_semantic3.png
# ├── 000187.yaml
# ├── 000187_camera0.png
# ├── 000187_camera1.png
# ├── 000187_camera2.png
# ├── 000187_camera3.png
# ├── 000187_gnss_imu.yaml
# ├── 000187_lidar.ply
# ├── 000187_semantic0.png
# ├── 000187_semantic1.png
# ├── 000187_semantic2.png
# ├── 000187_semantic3.png
# ├── 000188.yaml
# ├── 000188_camera0.png
# ├── 000188_camera1.png
# ├── 000188_camera2.png
# ├── 000188_camera3.png
# ├── 000188_gnss_imu.yaml
# ├── 000188_lidar.ply
# ├── 000188_semantic0.png
# ├── 000188_semantic1.png
# ├── 000188_semantic2.png
# ├── 000188_semantic3.png
# ├── 000189.yaml
# ├── 000189_camera0.png
# ├── 000189_camera1.png
# ├── 000189_camera2.png
# ├── 000189_camera3.png
# ├── 000189_gnss_imu.yaml
# ├── 000189_lidar.ply
# ├── 000189_semantic0.png
# ├── 000189_semantic1.png
# ├── 000189_semantic2.png
# ├── 000189_semantic3.png
# ├── 000190.yaml
# ├── 000190_camera0.png
# ├── 000190_camera1.png
# ├── 000190_camera2.png
# ├── 000190_camera3.png
# ├── 000190_gnss_imu.yaml
# ├── 000190_lidar.ply
# ├── 000190_semantic0.png
# ├── 000190_semantic1.png
# ├── 000190_semantic2.png
# ├── 000190_semantic3.png
# ├── 000191.yaml
# ├── 000191_camera0.png
# ├── 000191_camera1.png
# ├── 000191_camera2.png
# ├── 000191_camera3.png
# ├── 000191_gnss_imu.yaml
# ├── 000191_lidar.ply
# ├── 000191_semantic0.png
# ├── 000191_semantic1.png
# ├── 000191_semantic2.png
# ├── 000191_semantic3.png
# ├── 000192.yaml
# ├── 000192_camera0.png
# ├── 000192_camera1.png
# ├── 000192_camera2.png
# ├── 000192_camera3.png
# ├── 000192_gnss_imu.yaml
# ├── 000192_lidar.ply
# ├── 000192_semantic0.png
# ├── 000192_semantic1.png
# ├── 000192_semantic2.png
# ├── 000192_semantic3.png
# ├── 000193.yaml
# ├── 000193_camera0.png
# ├── 000193_camera1.png
# ├── 000193_camera2.png
# ├── 000193_camera3.png
# ├── 000193_gnss_imu.yaml
# ├── 000193_lidar.ply
# ├── 000193_semantic0.png
# ├── 000193_semantic1.png
# ├── 000193_semantic2.png
# ├── 000193_semantic3.png
# ├── 000194.yaml
# ├── 000194_camera0.png
# ├── 000194_camera1.png
# ├── 000194_camera2.png
# ├── 000194_camera3.png
# ├── 000194_gnss_imu.yaml
# ├── 000194_lidar.ply
# ├── 000194_semantic0.png
# ├── 000194_semantic1.png
# ├── 000194_semantic2.png
# ├── 000194_semantic3.png
# ├── 000195.yaml
# ├── 000195_camera0.png
# ├── 000195_camera1.png
# ├── 000195_camera2.png
# ├── 000195_camera3.png
# ├── 000195_gnss_imu.yaml
# ├── 000195_lidar.ply
# ├── 000195_semantic0.png
# ├── 000195_semantic1.png
# ├── 000195_semantic2.png
# ├── 000195_semantic3.png
# ├── 000196.yaml
# ├── 000196_camera0.png
# ├── 000196_camera1.png
# ├── 000196_camera2.png
# ├── 000196_camera3.png
# ├── 000196_gnss_imu.yaml
# ├── 000196_lidar.ply
# ├── 000196_semantic0.png
# ├── 000197.yaml
# ├── 000197_camera0.png
# ├── 000197_camera1.png
# ├── 000197_camera2.png
# ├── 000197_camera3.png
# ├── 000197_gnss_imu.yaml
# ├── 000197_lidar.ply
# ├── 000197_semantic0.png
# ├── 000197_semantic1.png
# ├── 000197_semantic2.png
# ├── 000197_semantic3.png
# ├── 000198.yaml
# ├── 000198_camera0.png
# ├── 000198_camera1.png
# ├── 000198_camera2.png
# ├── 000198_camera3.png
# ├── 000198_gnss_imu.yaml
# ├── 000198_lidar.ply
# ├── 000198_semantic0.png
# ├── 000198_semantic1.png
# ├── 000198_semantic2.png
# ├── 000199.yaml
# ├── 000199_camera0.png
# ├── 000199_camera1.png
# ├── 000199_camera2.png
# ├── 000199_camera3.png
# ├── 000199_gnss_imu.yaml
# ├── 000199_lidar.ply
# ├── 000199_semantic0.png
# ├── 000199_semantic1.png
# ├── 000199_semantic2.png
# ├── 000199_semantic3.png
# ├── 000200.yaml
# ├── 000200_camera0.png
# ├── 000200_camera1.png
# ├── 000200_camera2.png
# ├── 000200_camera3.png
# ├── 000200_gnss_imu.yaml
# ├── 000200_lidar.ply
# ├── 000200_semantic0.png
# ├── 000200_semantic1.png
# ├── 000200_semantic2.png
# ├── 000200_semantic3.png
# ├── 000201.yaml
# ├── 000201_camera0.png
# ├── 000201_camera1.png
# ├── 000201_camera2.png
# ├── 000201_camera3.png
# ├── 000201_gnss_imu.yaml
# ├── 000201_lidar.ply
# ├── 000201_semantic0.png
# ├── 000202.yaml
# ├── 000202_camera0.png
# ├── 000202_camera1.png
# ├── 000202_camera2.png
# ├── 000202_camera3.png
# ├── 000202_gnss_imu.yaml
# ├── 000202_lidar.ply
# ├── 000202_semantic0.png
# ├── 000202_semantic1.png
# ├── 000202_semantic2.png
# ├── 000202_semantic3.png
# ├── 000203.yaml
# ├── 000203_camera0.png
# ├── 000203_camera1.png
# ├── 000203_camera2.png
# ├── 000203_camera3.png
# ├── 000203_gnss_imu.yaml
# ├── 000203_lidar.ply
# ├── 000203_semantic0.png
# ├── 000203_semantic1.png
# ├── 000203_semantic2.png
# ├── 000203_semantic3.png
# ├── 000204.yaml
# ├── 000204_camera0.png
# ├── 000204_camera1.png
# ├── 000204_camera2.png
# ├── 000204_camera3.png
# ├── 000204_gnss_imu.yaml
# ├── 000204_lidar.ply
# ├── 000204_semantic0.png
# ├── 000204_semantic1.png
# ├── 000204_semantic2.png
# ├── 000204_semantic3.png
# ├── 000205.yaml
# ├── 000205_camera0.png
# ├── 000205_camera1.png
# ├── 000205_camera2.png
# ├── 000205_camera3.png
# ├── 000205_gnss_imu.yaml
# ├── 000205_lidar.ply
# ├── 000205_semantic0.png
# ├── 000205_semantic1.png
# ├── 000205_semantic2.png
# ├── 000205_semantic3.png
# ├── 000206.yaml
# ├── 000206_camera0.png
# ├── 000206_camera1.png
# ├── 000206_camera2.png
# ├── 000206_camera3.png
# ├── 000206_gnss_imu.yaml
# ├── 000206_lidar.ply
# ├── 000206_semantic0.png
# ├── 000206_semantic1.png
# ├── 000206_semantic2.png
# ├── 000206_semantic3.png
# ├── 000207.yaml
# ├── 000207_camera0.png
# ├── 000207_camera1.png
# ├── 000207_camera2.png
# ├── 000207_camera3.png
# ├── 000207_gnss_imu.yaml
# ├── 000207_lidar.ply
# ├── 000207_semantic0.png
# ├── 000207_semantic1.png
# ├── 000207_semantic2.png
# ├── 000207_semantic3.png
# ├── 000208.yaml
# ├── 000208_camera0.png
# ├── 000208_camera1.png
# ├── 000208_camera2.png
# ├── 000208_camera3.png
# ├── 000208_gnss_imu.yaml
# ├── 000208_lidar.ply
# ├── 000208_semantic0.png
# ├── 000209.yaml
# ├── 000209_camera0.png
# ├── 000209_camera1.png
# ├── 000209_camera2.png
# ├── 000209_camera3.png
# ├── 000209_gnss_imu.yaml
# ├── 000209_lidar.ply
# ├── 000209_semantic0.png
# ├── 000209_semantic1.png
# ├── 000209_semantic2.png
# ├── 000209_semantic3.png
# ├── 000210.yaml
# ├── 000210_camera0.png
# ├── 000210_camera1.png
# ├── 000210_camera2.png
# ├── 000210_camera3.png
# ├── 000210_gnss_imu.yaml
# ├── 000210_lidar.ply
# ├── 000210_semantic0.png
# ├── 000210_semantic1.png
# ├── 000210_semantic2.png
# ├── 000210_semantic3.png
# ├── 000211.yaml
# ├── 000211_camera0.png
# ├── 000211_camera1.png
# ├── 000211_camera2.png
# ├── 000211_camera3.png
# ├── 000211_gnss_imu.yaml
# ├── 000211_lidar.ply
# ├── 000211_semantic0.png
# ├── 000211_semantic1.png
# ├── 000211_semantic2.png
# ├── 000211_semantic3.png
# ├── 000212.yaml
# ├── 000212_camera0.png
# ├── 000212_camera1.png
# ├── 000212_camera2.png
# ├── 000212_camera3.png
# ├── 000212_gnss_imu.yaml
# ├── 000212_lidar.ply
# ├── 000212_semantic0.png
# ├── 000212_semantic1.png
# ├── 000212_semantic2.png
# ├── 000212_semantic3.png
# ├── 000213.yaml
# ├── 000213_camera0.png
# ├── 000213_camera1.png
# ├── 000213_camera2.png
# ├── 000213_camera3.png
# ├── 000213_gnss_imu.yaml
# ├── 000213_lidar.ply
# ├── 000213_semantic0.png
# ├── 000213_semantic1.png
# ├── 000213_semantic2.png
# ├── 000213_semantic3.png
# ├── 000214.yaml
# ├── 000214_camera0.png
# ├── 000214_camera1.png
# ├── 000214_camera2.png
# ├── 000214_camera3.png
# ├── 000214_gnss_imu.yaml
# ├── 000214_lidar.ply
# ├── 000214_semantic0.png
# ├── 000214_semantic1.png
# ├── 000214_semantic2.png
# ├── 000214_semantic3.png
# ├── 000215.yaml
# ├── 000215_camera0.png
# ├── 000215_camera1.png
# ├── 000215_camera2.png
# ├── 000215_camera3.png
# ├── 000215_gnss_imu.yaml
# ├── 000215_lidar.ply
# ├── 000215_semantic0.png
# ├── 000215_semantic1.png
# ├── 000215_semantic2.png
# ├── 000215_semantic3.png
# ├── 000216.yaml
# ├── 000216_camera0.png
# ├── 000216_camera1.png
# ├── 000216_camera2.png
# ├── 000216_camera3.png
# ├── 000216_gnss_imu.yaml
# ├── 000216_lidar.ply
# ├── 000216_semantic0.png
# ├── 000216_semantic1.png
# ├── 000216_semantic2.png
# ├── 000216_semantic3.png
# ├── 000217.yaml
# ├── 000217_camera0.png
# ├── 000217_camera1.png
# ├── 000217_camera2.png
# ├── 000217_camera3.png
# ├── 000217_gnss_imu.yaml
# ├── 000217_lidar.ply
# ├── 000217_semantic0.png
# ├── 000217_semantic1.png
# ├── 000217_semantic2.png
# ├── 000217_semantic3.png
# ├── 000218.yaml
# ├── 000218_camera0.png
# ├── 000218_camera1.png
# ├── 000218_camera2.png
# ├── 000218_camera3.png
# ├── 000218_gnss_imu.yaml
# ├── 000218_lidar.ply
# ├── 000218_semantic0.png
# ├── 000218_semantic1.png
# ├── 000218_semantic2.png
# ├── 000218_semantic3.png
# ├── 000219.yaml
# ├── 000219_camera0.png
# ├── 000219_camera1.png
# ├── 000219_camera2.png
# ├── 000219_camera3.png
# ├── 000219_gnss_imu.yaml
# ├── 000219_lidar.ply
# ├── 000219_semantic0.png
# ├── 000219_semantic1.png
# ├── 000219_semantic2.png
# ├── 000219_semantic3.png
# ├── 000220.yaml
# ├── 000220_camera0.png
# ├── 000220_camera1.png
# ├── 000220_camera2.png
# ├── 000220_camera3.png
# ├── 000220_gnss_imu.yaml
# ├── 000220_lidar.ply
# ├── 000220_semantic0.png
# ├── 000221.yaml
# ├── 000221_camera0.png
# ├── 000221_camera1.png
# ├── 000221_camera2.png
# ├── 000221_camera3.png
# ├── 000221_gnss_imu.yaml
# ├── 000221_lidar.ply
# ├── 000221_semantic0.png
# ├── 000221_semantic1.png
# ├── 000221_semantic2.png
# ├── 000221_semantic3.png
# ├── 000222.yaml
# ├── 000222_camera0.png
# ├── 000222_camera1.png
# ├── 000222_camera2.png
# ├── 000222_camera3.png
# ├── 000222_gnss_imu.yaml
# ├── 000222_lidar.ply
# ├── 000222_semantic0.png
# ├── 000222_semantic1.png
# ├── 000222_semantic2.png
# ├── 000222_semantic3.png
# ├── 000223.yaml
# ├── 000223_camera0.png
# ├── 000223_camera1.png
# ├── 000223_camera2.png
# ├── 000223_camera3.png
# ├── 000223_gnss_imu.yaml
# ├── 000223_lidar.ply
# ├── 000223_semantic0.png
# ├── 000223_semantic1.png
# ├── 000223_semantic2.png
# ├── 000223_semantic3.png
# ├── 000224.yaml
# ├── 000224_camera0.png
# ├── 000224_camera1.png
# ├── 000224_camera2.png
# ├── 000224_camera3.png
# ├── 000224_gnss_imu.yaml
# ├── 000224_lidar.ply
# ├── 000224_semantic0.png
# ├── 000224_semantic1.png
# ├── 000224_semantic2.png
# ├── 000224_semantic3.png
# ├── 000225.yaml
# ├── 000225_camera0.png
# ├── 000225_camera1.png
# ├── 000225_camera2.png
# ├── 000225_camera3.png
# ├── 000225_gnss_imu.yaml
# ├── 000225_lidar.ply
# ├── 000225_semantic0.png
# ├── 000225_semantic1.png
# ├── 000225_semantic2.png
# ├── 000225_semantic3.png
# ├── 000226.yaml
# ├── 000226_camera0.png
# ├── 000226_camera1.png
# ├── 000226_camera2.png
# ├── 000226_camera3.png
# ├── 000226_gnss_imu.yaml
# ├── 000226_lidar.ply
# ├── 000226_semantic0.png
# ├── 000226_semantic1.png
# ├── 000226_semantic2.png
# ├── 000226_semantic3.png
# ├── 000227.yaml
# ├── 000227_camera0.png
# ├── 000227_camera1.png
# ├── 000227_camera2.png
# ├── 000227_camera3.png
# ├── 000227_gnss_imu.yaml
# ├── 000227_lidar.ply
# ├── 000227_semantic0.png
# ├── 000227_semantic1.png
# ├── 000227_semantic2.png
# ├── 000227_semantic3.png
# ├── 000228.yaml
# ├── 000228_camera0.png
# ├── 000228_camera1.png
# ├── 000228_camera2.png
# ├── 000228_camera3.png
# ├── 000228_gnss_imu.yaml
# ├── 000228_lidar.ply
# ├── 000228_semantic0.png
# ├── 000228_semantic1.png
# ├── 000228_semantic2.png
# ├── 000228_semantic3.png
# ├── 000229.yaml
# ├── 000229_camera0.png
# ├── 000229_camera1.png
# ├── 000229_camera2.png
# ├── 000229_camera3.png
# ├── 000229_gnss_imu.yaml
# ├── 000229_lidar.ply
# ├── 000229_semantic0.png
# ├── 000229_semantic1.png
# ├── 000229_semantic2.png
# ├── 000229_semantic3.png
# ├── 000230.yaml
# ├── 000230_camera0.png
# ├── 000230_camera1.png
# ├── 000230_camera2.png
# ├── 000230_camera3.png
# ├── 000230_gnss_imu.yaml
# ├── 000230_lidar.ply
# ├── 000230_semantic0.png
# ├── 000230_semantic1.png
# ├── 000230_semantic2.png
# ├── 000230_semantic3.png
# ├── 000231.yaml
# ├── 000231_camera0.png
# ├── 000231_camera1.png
# ├── 000231_camera2.png
# ├── 000231_camera3.png
# ├── 000231_gnss_imu.yaml
# ├── 000231_lidar.ply
# ├── 000231_semantic0.png
# ├── 000231_semantic1.png
# ├── 000231_semantic2.png
# ├── 000231_semantic3.png
# ├── 000232.yaml
# ├── 000232_camera0.png
# ├── 000232_camera1.png
# ├── 000232_camera2.png
# ├── 000232_camera3.png
# ├── 000232_gnss_imu.yaml
# ├── 000232_lidar.ply
# ├── 000233.yaml
# ├── 000233_camera0.png
# ├── 000233_camera1.png
# ├── 000233_camera2.png
# ├── 000233_camera3.png
# ├── 000233_gnss_imu.yaml
# ├── 000233_lidar.ply
# ├── 000233_semantic0.png
# ├── 000233_semantic1.png
# ├── 000233_semantic2.png
# ├── 000233_semantic3.png
# ├── 000234.yaml
# ├── 000234_camera0.png
# ├── 000234_camera1.png
# ├── 000234_camera2.png
# ├── 000234_camera3.png
# ├── 000234_gnss_imu.yaml
# ├── 000234_lidar.ply
# ├── 000234_semantic0.png
# ├── 000234_semantic1.png
# ├── 000234_semantic2.png
# ├── 000234_semantic3.png
# ├── 000235.yaml
# ├── 000235_camera0.png
# ├── 000235_camera1.png
# ├── 000235_camera2.png
# ├── 000235_camera3.png
# ├── 000235_gnss_imu.yaml
# ├── 000235_lidar.ply
# ├── 000235_semantic0.png
# ├── 000235_semantic1.png
# ├── 000235_semantic2.png
# ├── 000235_semantic3.png
# ├── 000236.yaml
# ├── 000236_camera0.png
# ├── 000236_camera1.png
# ├── 000236_camera2.png
# ├── 000236_camera3.png
# ├── 000236_gnss_imu.yaml
# ├── 000236_lidar.ply
# ├── 000236_semantic0.png
# ├── 000236_semantic1.png
# ├── 000236_semantic2.png
# ├── 000236_semantic3.png
# ├── 000237.yaml
# ├── 000237_camera0.png
# ├── 000237_camera1.png
# ├── 000237_camera2.png
# ├── 000237_camera3.png
# ├── 000237_gnss_imu.yaml
# ├── 000237_lidar.ply
# ├── 000237_semantic0.png
# ├── 000237_semantic1.png
# ├── 000237_semantic2.png
# ├── 000237_semantic3.png
# ├── 000238.yaml
# ├── 000238_camera0.png
# ├── 000238_camera1.png
# ├── 000238_camera2.png
# ├── 000238_camera3.png
# ├── 000238_gnss_imu.yaml
# ├── 000238_lidar.ply
# ├── 000238_semantic0.png
# ├── 000238_semantic1.png
# ├── 000238_semantic2.png
# ├── 000238_semantic3.png
# ├── 000239.yaml
# ├── 000239_camera0.png
# ├── 000239_camera1.png
# ├── 000239_camera2.png
# ├── 000239_camera3.png
# ├── 000239_gnss_imu.yaml
# ├── 000239_lidar.ply
# ├── 000239_semantic0.png
# ├── 000239_semantic1.png
# ├── 000239_semantic2.png
# ├── 000239_semantic3.png
# ├── 000240.yaml
# ├── 000240_camera0.png
# ├── 000240_camera1.png
# ├── 000240_camera2.png
# ├── 000240_camera3.png
# ├── 000240_gnss_imu.yaml
# ├── 000240_lidar.ply
# ├── 000240_semantic0.png
# ├── 000240_semantic1.png
# ├── 000240_semantic2.png
# ├── 000240_semantic3.png
# ├── 000241.yaml
# ├── 000241_camera0.png
# ├── 000241_camera1.png
# ├── 000241_camera2.png
# ├── 000241_camera3.png
# ├── 000241_gnss_imu.yaml
# ├── 000241_lidar.ply
# ├── 000241_semantic0.png
# ├── 000241_semantic1.png
# ├── 000241_semantic2.png
# ├── 000241_semantic3.png
# ├── 000242.yaml
# ├── 000242_camera0.png
# ├── 000242_camera1.png
# ├── 000242_camera2.png
# ├── 000242_camera3.png
# ├── 000242_gnss_imu.yaml
# ├── 000242_lidar.ply
# ├── 000242_semantic0.png
# ├── 000242_semantic1.png
# ├── 000242_semantic2.png
# ├── 000242_semantic3.png
# ├── 000243.yaml
# ├── 000243_camera0.png
# ├── 000243_camera1.png
# ├── 000243_camera2.png
# ├── 000243_camera3.png
# ├── 000243_gnss_imu.yaml
# ├── 000243_lidar.ply
# ├── 000243_semantic0.png
# ├── 000243_semantic1.png
# ├── 000243_semantic2.png
# ├── 000243_semantic3.png
# ├── 000244.yaml
# ├── 000244_camera0.png
# ├── 000244_camera1.png
# ├── 000244_camera2.png
# ├── 000244_camera3.png
# ├── 000244_gnss_imu.yaml
# ├── 000244_lidar.ply
# ├── 000244_semantic0.png
# ├── 000244_semantic1.png
# ├── 000244_semantic2.png
# ├── 000244_semantic3.png
# ├── 000245.yaml
# ├── 000245_camera0.png
# ├── 000245_camera1.png
# ├── 000245_camera2.png
# ├── 000245_camera3.png
# ├── 000245_gnss_imu.yaml
# ├── 000245_lidar.ply
# ├── 000245_semantic0.png
# ├── 000245_semantic1.png
# ├── 000245_semantic2.png
# ├── 000245_semantic3.png
# ├── 000246.yaml
# ├── 000246_camera0.png
# ├── 000246_camera1.png
# ├── 000246_camera2.png
# ├── 000246_camera3.png
# ├── 000246_gnss_imu.yaml
# ├── 000246_lidar.ply
# ├── 000246_semantic0.png
# ├── 000246_semantic1.png
# ├── 000246_semantic2.png
# ├── 000246_semantic3.png
# ├── 000247.yaml
# ├── 000247_camera0.png
# ├── 000247_camera1.png
# ├── 000247_camera2.png
# ├── 000247_camera3.png
# ├── 000247_gnss_imu.yaml
# ├── 000247_lidar.ply
# ├── 000247_semantic0.png
# ├── 000247_semantic1.png
# ├── 000247_semantic2.png
# ├── 000247_semantic3.png
# ├── 000248.yaml
# ├── 000248_camera0.png
# ├── 000248_camera1.png
# ├── 000248_camera2.png
# ├── 000248_camera3.png
# ├── 000248_gnss_imu.yaml
# ├── 000248_lidar.ply
# ├── 000248_semantic0.png
# ├── 000248_semantic1.png
# ├── 000248_semantic2.png
# ├── 000248_semantic3.png
# ├── 000249.yaml
# ├── 000249_camera0.png
# ├── 000249_camera1.png
# ├── 000249_camera2.png
# ├── 000249_camera3.png
# ├── 000249_gnss_imu.yaml
# ├── 000249_lidar.ply
# ├── 000249_semantic0.png
# ├── 000249_semantic1.png
# ├── 000249_semantic2.png
# ├── 000249_semantic3.png
# ├── 000250_semantic0.png
# ├── 000250_semantic1.png
# ├── 000250_semantic2.png
# └── 000250_semantic3.png

# %% [markdown]
# Here we see the images (in .png format) produced by the selected AGENT_ID's various cameras, indexed by the `frame` ID. There are also .yaml files for each frame. Let's quickly inspect one of these .yaml files to see what metadata is provided.

# %%
FRAME_ID = "000060"
FRAME_PATH = DIR_EXTRACTED+"/"+str(AGENT_ID)+"/"+str(FRAME_ID)+".yaml"
print(str(FRAME_PATH))
print("metadata for frame at:", FRAME_PATH)
with open(FRAME_PATH, "r") as f:
    frame_metadata = yaml.safe_load(f)
print(yaml.safe_dump(frame_metadata, sort_keys=False))
# Out:
# ./exploration/data/extracted/rcnj_cn_s/1011/000060.yaml
# metadata for frame at: ./exploration/data/extracted/rcnj_cn_s/1011/000060.yaml
# RSU: false
# camera0:
#   cords:
#   - 68.41932678222656
#   - -42.19554901123047
#   - 3.808724880218506
#   - 0.04656583443284035
#   - -138.46652221679688
#   - 4.805174350738525
#   extrinsic:
#   - - 1.0
#     - -1.889048141136061e-16
#     - -3.3023009692718086e-18
#     - -0.9499967603398396
#   - - -3.127514015704538e-17
#     - 0.9999999999999998
#     - 6.327602932046738e-18
#     - 6.475694505070351e-07
#   - - 5.853078658478853e-18
#     - -1.4994452834307173e-17
#     - 0.9999999999999999
#     - 0.4499992445328216
#   - -50.844234466552734
#   - 39.0
# - - 60.778724670410156
#   - -53.226680755615234
#   - 39.0
# - - 59.96884536743164
#   - -55.69633102416992
#   - 39.0
# - - 59.777557373046875
#   - -56.37004089355469
#   - 39.0
# predicted_ego_pos:
# - 68.66329193115234
# - -41.97787857055664
# - 2.3261260986328125
# - 0.04656583443284035
# - -138.46652221679688
# - 4.805174350738525
# true_ego_pos:
# - 68.66329193115234
# - -41.97787857055664
# - 2.3261260986328125
# - 0.04656583443284035
# - -138.46652221679688
# - 4.805174350738525
# vehicles:
#   1025:
#     angle:
#     - -0.052093397825956345
#     - -79.91226959228516
#     - 4.743265628814697
#     bp_id: vehicle.lincoln.mkz_2017
#     center:
#     - 0.004046587739139795
#     - -2.3126601433887117e-07
#     - 0.7188604474067688
#     class: car
#     color: 0, 0, 255
#     dist: 45.59115982055664
#     extent:
#     - 2.4508416652679443
#     - 1.0641621351242065
#     - 0.7553732395172119
#     location:
#     - 62.10791778564453
#     - -86.91078186035156
#     - 6.402285099029541
#     relative_angle: 58.55425262451172
#     speed: 27.921569795082934
#   1075:
#     angle:
#     - -0.007965086959302425
#     - 100.36516571044922
#     - -4.730069637298584
#     bp_id: vehicle.dodge.charger_2020
#     center:
#     - -0.006225633434951305
#     - -1.1771917343139648e-06
#     - 0.7655779719352722
#     class: car
#     color: 168,0,27
#     dist: 49.57381057739258
#     extent:
#     - 2.5030298233032227
#     - 1.0485419034957886
#     - 0.7673624753952026
#     location:
#     - 59.5821533203125
#     - -90.5228271484375
#     - 6.625391006469727
#     relative_angle: -121.1683120727539
#     speed: 26.47415158892431
#   1077:
#     angle:
#     - -0.17077665030956268
#     - 73.79939270019531
#     - -4.833649635314941
#     bp_id: vehicle.carlamotors.carlacola
#     center:
#     - 5.245208853921213e-07
#     - 1.591443947290827e-06
#     - 1.2337223291397095
#     class: truck
#     color: 255,68,0
#     dist: 14.87833023071289
#     extent:
#     - 2.601919174194336
#     - 1.3134948015213013
#     - 1.2337223291397095
#     location:
#     - 73.77147674560547
#     - -28.060333251953125
#     - 1.0718986988067627
#     relative_angle: -147.7340850830078
#     speed: 30.927785248723296
#   1087:
#     angle:
#     - 0.008529790677130222
#     - 75.76213073730469
#     - -4.510643005371094
#     bp_id: vehicle.chevrolet.impala
#     center:
#     - 5.710124969482422e-05
#     - 0.001790678477846086
#     - 0.7014920115470886
#     class: car
#     color: 158,149,129
#     dist: 18.396833419799805
#     extent:
#     - 2.6787397861480713
#     - 1.0166014432907104
#     - 0.7053293585777283
#     location:
#     - 56.81985855102539
#     - -55.977577209472656
#     - 3.8042876720428467
#     relative_angle: -145.77134704589844
#     speed: 14.652877711098366
#   1091:
#     angle:
#     - -0.020354820415377617
#     - -79.01602935791016
#     - 4.9314985275268555
#     bp_id: vehicle.carlamotors.carlacola
#     center:
#     - -3.7193296975601697e-07
#     - 2.689361508600996e-06
#     - 1.2337223291397095
#     class: truck
#     color: 255,68,0
#     dist: 59.07536697387695
#     extent:
#     - 2.601919174194336
#     - 1.3134948015213013
#     - 1.2337223291397095
#     location:
#     - 64.73578643798828
#     - -100.69337463378906
#     - 7.518856525421143
#     relative_angle: 59.45049285888672
#     speed: 19.747792429655863
#   1094:
#     angle:
#     - 0.1581786423921585
#     - 93.99520111083984
#     - -4.34624719619751
#     bp_id: vehicle.nissan.micra
#     center:
#     - -1.962184796866495e-06
#     - 0.0009687041747383773
#     - 0.7812460660934448
#     class: car
#     color: 187,0,0
#     dist: 28.323129653930664
#     extent:
#     - 1.8166879415512085
#     - 0.9225568771362305
#     - 0.7506412863731384
#     location:
#     - 56.16558074951172
#     - -67.28489685058594
#     - 4.6844482421875
#     relative_angle: -127.53827667236328
#     speed: 11.01964515549268
#   1096:
#     angle:
#     - -2.084686040878296
#     - 50.96004867553711
#     - -4.146539211273193
#     bp_id: vehicle.bh.crossbike
#     center:
#     - 0.0002929687325377017
#     - 68.52550506591797
#     - 0.5411922931671143
#     class: bicycle
#     color: 255,160,145
#     dist: 6.380521774291992
#     extent:
#     - 0.7436444163322449
#     - 0.0
#     - 0.5397894978523254
#     location:
#     - 62.82327651977539
#     - -44.507728576660156
#     - 2.779040813446045
#     relative_angle: -170.57342910766602
#     speed: 17.750028331810427

# %% [markdown]
# Which we see contains the positions of the agents/vehicles in the frame, relative to the position of the data-producing agent/vehicle's camera. Let's look at a few of the camera images.

# %%
print('returning all images for cameras at: ', DIR_EXTRACTED+"/"+str(AGENT_ID))
imgs = find_imgs(DIR_EXTRACTED+"/"+str(AGENT_ID), camera=None, ext=".png", limit=None)
print('found ', len(imgs), ' images')

sizes = list_image_sizes(imgs)
show_images_grid(imgs, rows=2, cols=3, randomize = True)
# Out:
# returning all images for cameras at:  ./exploration/data/extracted/rcnj_cn_s/1011
# found  760  images
# Found 1 unique image size(s) in 760 images:
#   1920 × 1080

# %% [markdown]
# ## Build an Index
#
# Parse through the various folders to build an index suitable for ML applications.

# %%
df = build_index(DIR_EXTRACTED, camera=None, ext='.png', limit=None)

# %% [markdown]
# Inspect the size of the dataframe

# %%
df.shape
# Out:
# (3800, 8)

# %% [markdown]
# Show me some basic info

# %%
df.info
# Out:
# <bound method DataFrame.info of       data_name prefix weather density  agent_id  frame_id   camera  \
# 0     rcnj_cn_s   rcnj      cn       s        -2        60  camera0
# 1     rcnj_cn_s   rcnj      cn       s        -2        60  camera1
# 2     rcnj_cn_s   rcnj      cn       s        -2        60  camera2
# 3     rcnj_cn_s   rcnj      cn       s        -2        60  camera3
# 4     rcnj_cn_s   rcnj      cn       s        -2        61  camera0
# ...         ...    ...     ...     ...       ...       ...      ...
# 3795  rcnj_cn_s   rcnj      cn       s      1039       248  camera3
# 3796  rcnj_cn_s   rcnj      cn       s      1039       249  camera0
# 3797  rcnj_cn_s   rcnj      cn       s      1039       249  camera1
# 3798  rcnj_cn_s   rcnj      cn       s      1039       249  camera2
# 3799  rcnj_cn_s   rcnj      cn       s      1039       249  camera3
#
#                                              image_path
# 0     exploration/data/extracted/rcnj_cn_s/-2/000060...
# 1     exploration/data/extracted/rcnj_cn_s/-2/000060...
# 2     exploration/data/extracted/rcnj_cn_s/-2/000060...
# 3     exploration/data/extracted/rcnj_cn_s/-2/000060...
# 4     exploration/data/extracted/rcnj_cn_s/-2/000061...
# ...                                                 ...
# 3795  exploration/data/extracted/rcnj_cn_s/1039/0002...
# 3796  exploration/data/extracted/rcnj_cn_s/1039/0002...
# 3797  exploration/data/extracted/rcnj_cn_s/1039/0002...
# 3798  exploration/data/extracted/rcnj_cn_s/1039/0002...
# 3799  exploration/data/extracted/rcnj_cn_s/1039/0002...
#
# [3800 rows x 8 columns]>

# %% [markdown]
# Look at the first few rows

# %%
df.head()
# Out:
#    data_name prefix weather density  agent_id  frame_id   camera  \
# 0  rcnj_cn_s   rcnj      cn       s        -2        60  camera0
# 1  rcnj_cn_s   rcnj      cn       s        -2        60  camera1
# 2  rcnj_cn_s   rcnj      cn       s        -2        60  camera2
# 3  rcnj_cn_s   rcnj      cn       s        -2        60  camera3
# 4  rcnj_cn_s   rcnj      cn       s        -2        61  camera0
#
#                                           image_path
# 0  exploration/data/extracted/rcnj_cn_s/-2/000060...
# 1  exploration/data/extracted/rcnj_cn_s/-2/000060...
# 2  exploration/data/extracted/rcnj_cn_s/-2/000060...
# 3  exploration/data/extracted/rcnj_cn_s/-2/000060...
# 4  exploration/data/extracted/rcnj_cn_s/-2/000061...

# %% [markdown]
# Save the index for later

# %%
FILENAME_INDEX = 'data_index'
DIR_INDEX = DATA_DIR+"/indexed"

index_path = save_index(df, DIR_INDEX, FILENAME_INDEX, '.csv')
print("Saved to:", index_path)
# Out:
# Saved to: exploration/data/indexed/data_index.csv

# %% [markdown]
# ## Extend to multiple datasets
#
# Extend the methods above to handle multiple datasets (i.e., pulling form multiple agents)

# %%
PREFIXES = ["rcnj"]
WEATHERS = ["cn", "hrn"]
DENSITIES = ["s"]

filenames = build_filenames(PREFIXES, WEATHERS, DENSITIES, VALID_PREFIX, VALID_WEATHER, VALID_DENSITY, ".7z")
downloaded = download_files(
    base_url=BASE_URL,
    destinations_dir=Path(DATA_DIR),
    filenames=filenames,
    timeout=60,
    max_size_GB=10
)

extracted_dirs = extract_files(
    source_dir=Path(DATA_DIR),
    filenames=filenames,  # Already built from build_filenames() above
    output_dir=Path(DATA_DIR) / "extracted",
    data_format="7z"
)
# Out:
# [SKIP] rcnj_cn_s.7z already present in exploration/data.
# [SKIP] rcnj_hrn_s.7z already present in exploration/data.
# Already extracted, skipping:
#   exploration/data/extracted/rcnj_cn_s
# [EXTRACT] rcnj_cn_s.7z successful.
# Already extracted, skipping:
#   exploration/data/extracted/rcnj_hrn_s
# [EXTRACT] rcnj_hrn_s.7z successful.

# %%
df_multi = build_index_multi(extracted_dirs, camera=None, ext='.png', limit=None)
FILENAME_INDEX_MULTI = 'data_index_multi'
index_path_multi = save_index(df_multi, DIR_INDEX, FILENAME_INDEX_MULTI, '.csv')
print("Saved to:", index_path_multi)
# Out:
# Saved to: exploration/data/indexed/data_index_multi.csv
